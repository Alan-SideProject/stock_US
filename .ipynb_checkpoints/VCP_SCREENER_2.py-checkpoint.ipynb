# %% [markdown]
# # pip install
# - pip install pandas
# - pip install numpy
# - pip install yfinance
# https://pypi.org/project/yfinance/
# - pip install finviz
# https://pypi.org/project/finviz/
# - pip install finvizfinance
# https://pypi.org/project/finvizfinance/
#
# # Import required libs
# - import yfinance as yf
# - from finviz.screener import Screener
# - import pandas as pd
# - import numpy as np
# - from tqdm import tqdm
# - from scipy.stats import linregress
# - from IPython.display import Image ,display
# - from IPython.core.display import HTML
# - from finvizfinance.quote import finvizfinance
#
# # ignore warning caused by python version
# - warnings.filterwarnings('ignore')

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import yfinance as yf
from finviz.screener import Screener
import pandas as pd 
import numpy as np
from tqdm import tqdm
from scipy.stats import linregress
from IPython.display import Image ,display
from IPython.core.display import HTML
from finvizfinance.quote import finvizfinance

# %% [markdown]
# # retrieve data from finviz
# - filters = ['cap_midover','sh_curvol_o50','sh_price_o10','fa_epsqoq_o5','fa_salesqoq_o5','sh_instown_o10','ta_highlow52w_b0to10h']
# - stock_list = Screener(filters = filters , table = 'Performance' , order = 'Price')
# - stock_list.data

# %%
#using finviz screener
#filters = ['cap_midover','sh_curvol_o50','sh_price_o10','fa_epsqoq_o5','fa_salesqoq_o5','sh_instown_o10','ta_highlow52w_b0to10h']
filters = ['cap_smallover','fa_salesqoq_o10','sh_curvol_o50','sh_instown_o10','sh_price_o15','ta_highlow52w_b0to10h','ta_sma200_sb50','ta_sma50_pa']
stock_list = Screener(filters = filters , table = 'Performance' , order = 'Price')

#https://finviz.com/screener.ashx?v=111&f=cap_midover,fa_epsqoq_o5,fa_salesqoq_o5,sh_curvol_o50,sh_instown_o10,sh_price_o10&ft=3
stock_list
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 14/14 [00:17<00:00,  1.25s/it]
# tickers: ()
# filters: ('cap_smallover', 'fa_salesqoq_o10', 'sh_curvol_o50', 'sh_instown_o10', 'sh_price_o15', 'ta_highlow52w_b0to10h', 'ta_sma200_sb50', 'ta_sma50_pa')
# rows: 269
# order: Price
# signal:
# table: 141
# table: []

# %%
stock_list.data
# Out:
# [{'No.': '1',
#   'Ticker': 'ACRE',
#   'Perf Week': '-2.43%',
#   'Perf Month': '-3.54%',
#   'Perf Quart': '2.41%',
#   'Perf Half': '11.26%',
#   'Perf Year': '61.56%',
#   'Perf YTD': '28.73%',
#   'Volatility W': '1.64%',
#   'Volatility M': '1.52%',
#   'Recom': '2.00',
#   'Avg Volume': '457.61K',
#   'Rel Volume': '0.26',
#   'Price': '15.33',
#   'Change': '0.39%',
#   'Volume': '77,232'},
#  {'No.': '2',
#   'Ticker': 'CPLG',
#   'Perf Week': '1.23%',
#   'Perf Month': '7.89%',
#   'Perf Quart': '41.51%',
#   'Perf Half': '65.92%',
#   'Perf Year': '173.81%',
#   'Perf YTD': '126.45%',
#   'Volatility W': '3.20%',
#   'Volatility M': '3.52%',
#   'Recom': '3.00',
#   'Avg Volume': '214.56K',
#   'Rel Volume': '0.55',
#   'Price': '15.51',
#   'Change': '-0.45%',
#   'Volume': '77,180'},
#  {'No.': '3',
#   'Ticker': 'MWA',
#   'Perf Week': '-4.21%',
#   'Perf Month': '-6.69%',
#   'Perf Quart': '6.32%',
#   'Perf Half': '7.80%',
#   'Perf Year': '46.64%',
#   'Perf YTD': '24.96%',
#   'Volatility W': '3.28%',
#   'Volatility M': '2.35%',
#   'Recom': '2.60',
#   'Avg Volume': '919.21K',
#   'Rel Volume': '0.60',
#   'Price': '15.66',
#   'Change': '1.23%',
#   'Volume': '358,173'},
#  {'No.': '4',
#   'Ticker': 'TILE',
#   'Perf Week': '4.13%',
#   'Perf Month': '7.20%',
#   'Perf Quart': '2.49%',
#   'Perf Half': '20.68%',
#   'Perf Year': '136.97%',
#   'Perf YTD': '48.95%',
#   'Volatility W': '2.83%',
#   'Volatility M': '2.86%',
#   'Recom': '2.70',
#   'Avg Volume': '289.32K',
#   'Rel Volume': '1.03',
#   'Price': '15.81',
#   'Change': '1.09%',
#   'Volume': '193,374'},
#  {'No.': '5',
#   'Ticker': 'APLE',
#   'Perf Week': '-1.42%',
#   'Perf Month': '4.32%',
#   'Perf Quart': '6.77%',
#   'Perf Half': '6.70%',
#   'Perf Year': '53.91%',
#   'Perf YTD': '23.39%',
#   'Volatility W': '3.05%',
#   'Volatility M': '2.65%',
#   'Recom': '1.90',
#   'Avg Volume': '1.72M',
#   'Rel Volume': '0.57',
#   'Price': '15.90',
#   'Change': '-0.22%',
#   'Volume': '638,726'},
#  {'No.': '6',
#   'Ticker': 'VG',
#   'Perf Week': '-1.34%',
#   'Perf Month': '10.91%',
#   'Perf Quart': '11.13%',
#   'Perf Half': '29.67%',
#   'Perf Year': '59.31%',
#   'Perf YTD': '25.59%',
#   'Volatility W': '2.19%',
#   'Volatility M': '3.00%',
#   'Recom': '2.00',
#   'Avg Volume': '1.94M',
#   'Rel Volume': '0.43',
#   'Price': '16.18',
#   'Change': '0.06%',
#   'Volume': '542,093'},
#  {'No.': '7',
#   'Ticker': 'SITC',
#   'Perf Week': '4.99%',
#   'Perf Month': '1.49%',
#   'Perf Quart': '9.48%',
#   'Perf Half': '17.73%',
#   'Perf Year': '115.22%',
#   'Perf YTD': '62.06%',
#   'Volatility W': '2.96%',
#   'Volatility M': '2.48%',
#   'Recom': '2.60',
#   'Avg Volume': '1.47M',
#   'Rel Volume': '1.17',
#   'Price': '16.36',
#   'Change': '-0.21%',
#   'Volume': '1,116,106'},
#  {'No.': '8',
#   'Ticker': 'RADI',
#   'Perf Week': '-0.78%',
#   'Perf Month': '-8.28%',
#   'Perf Quart': '11.86%',
#   'Perf Half': '12.63%',
#   'Perf Year': '98.80%',
#   'Perf YTD': '28.40%',
#   'Volatility W': '2.57%',
#   'Volatility M': '3.03%',
#   'Recom': '1.70',
#   'Avg Volume': '652.17K',
#   'Rel Volume': '0.71',
#   'Price': '16.66',
#   'Change': '0.94%',
#   'Volume': '301,547'},
#  {'No.': '9',
#   'Ticker': 'INVA',
#   'Perf Week': '0.82%',
#   'Perf Month': '11.23%',
#   'Perf Quart': '26.02%',
#   'Perf Half': '40.16%',
#   'Perf Year': '68.69%',
#   'Perf YTD': '39.14%',
#   'Volatility W': '3.03%',
#   'Volatility M': '2.93%',
#   'Recom': '4.00',
#   'Avg Volume': '757.61K',
#   'Rel Volume': '0.51',
#   'Price': '16.75',
#   'Change': '-2.81%',
#   'Volume': '248,899'},
#  {'No.': '10',
#   'Ticker': 'ERJ',
#   'Perf Week': '1.09%',
#   'Perf Month': '-0.40%',
#   'Perf Quart': '23.06%',
#   'Perf Half': '70.31%',
#   'Perf Year': '286.18%',
#   'Perf YTD': '158.59%',
#   'Volatility W': '4.65%',
#   'Volatility M': '4.23%',
#   'Recom': '2.50',
#   'Avg Volume': '2.09M',
#   'Rel Volume': '0.97',
#   'Price': '16.89',
#   'Change': '-4.09%',
#   'Volume': '1,317,955'},
#  {'No.': '11',
#   'Ticker': 'CNHI',
#   'Perf Week': '-2.39%',
#   'Perf Month': '0.66%',
#   'Perf Quart': '2.89%',
#   'Perf Half': '5.74%',
#   'Perf Year': '114.87%',
#   'Perf YTD': '30.53%',
#   'Volatility W': '2.13%',
#   'Volatility M': '1.89%',
#   'Recom': '2.40',
#   'Avg Volume': '2.64M',
#   'Rel Volume': '0.52',
#   'Price': '16.90',
#   'Change': '0.84%',
#   'Volume': '894,073'},
#  {'No.': '12',
#   'Ticker': 'ASLE',
#   'Perf Week': '1.41%',
#   'Perf Month': '25.56%',
#   'Perf Quart': '38.47%',
#   'Perf Half': '42.72%',
#   'Perf Year': '68.52%',
#   'Perf YTD': '28.56%',
#   'Volatility W': '4.00%',
#   'Volatility M': '4.39%',
#   'Recom': '3.00',
#   'Avg Volume': '77.42K',
#   'Rel Volume': '1.43',
#   'Price': '17.42',
#   'Change': '1.04%',
#   'Volume': '71,701'},
#  {'No.': '13',
#   'Ticker': 'PAM',
#   'Perf Week': '8.99%',
#   'Perf Month': '4.76%',
#   'Perf Quart': '19.37%',
#   'Perf Half': '20.40%',
#   'Perf Year': '67.53%',
#   'Perf YTD': '31.06%',
#   'Volatility W': '3.21%',
#   'Volatility M': '4.73%',
#   'Recom': '3.30',
#   'Avg Volume': '103.28K',
#   'Rel Volume': '1.80',
#   'Price': '18.39',
#   'Change': '1.83%',
#   'Volume': '120,377'},
#  {'No.': '14',
#   'Ticker': 'EFC',
#   'Perf Week': '-1.28%',
#   'Perf Month': '0.00%',
#   'Perf Quart': '-1.64%',
#   'Perf Half': '7.84%',
#   'Perf Year': '45.76%',
#   'Perf YTD': '25.13%',
#   'Volatility W': '1.86%',
#   'Volatility M': '1.43%',
#   'Recom': '2.10',
#   'Avg Volume': '661.33K',
#   'Rel Volume': '0.60',
#   'Price': '18.72',
#   'Change': '0.81%',
#   'Volume': '257,927'},
#  {'No.': '15',
#   'Ticker': 'CWK',
#   'Perf Week': '1.62%',
#   'Perf Month': '4.55%',
#   'Perf Quart': '9.91%',
#   'Perf Half': '15.00%',
#   'Perf Year': '66.17%',
#   'Perf YTD': '27.17%',
#   'Volatility W': '2.40%',
#   'Volatility M': '2.55%',
#   'Recom': '2.20',
#   'Avg Volume': '1.34M',
#   'Rel Volume': '0.43',
#   'Price': '18.80',
#   'Change': '-0.32%',
#   'Volume': '377,079'},
#  {'No.': '16',
#   'Ticker': 'ABR',
#   'Perf Week': '1.62%',
#   'Perf Month': '2.61%',
#   'Perf Quart': '6.43%',
#   'Perf Half': '18.84%',
#   'Perf Year': '59.16%',
#   'Perf YTD': '33.00%',
#   'Volatility W': '1.66%',
#   'Volatility M': '1.67%',
#   'Recom': '2.20',
#   'Avg Volume': '1.33M',
#   'Rel Volume': '0.59',
#   'Price': '18.95',
#   'Change': '0.50%',
#   'Volume': '506,464'},
#  {'No.': '17',
#   'Ticker': 'GT',
#   'Perf Week': '3.11%',
#   'Perf Month': '18.84%',
#   'Perf Quart': '15.07%',
#   'Perf Half': '7.31%',
#   'Perf Year': '130.28%',
#   'Perf YTD': '76.35%',
#   'Volatility W': '4.28%',
#   'Volatility M': '3.82%',
#   'Recom': '2.20',
#   'Avg Volume': '3.36M',
#   'Rel Volume': '0.85',
#   'Price': '19.00',
#   'Change': '-1.27%',
#   'Volume': '1,857,446'},
#  {'No.': '18',
#   'Ticker': 'SLRC',
#   'Perf Week': '0.99%',
#   'Perf Month': '3.19%',
#   'Perf Quart': '0.68%',
#   'Perf Half': '2.76%',
#   'Perf Year': '18.97%',
#   'Perf YTD': '10.68%',
#   'Volatility W': '1.25%',
#   'Volatility M': '1.67%',
#   'Recom': '1.90',
#   'Avg Volume': '126.34K',
#   'Rel Volume': '0.75',
#   'Price': '19.36',
#   'Change': '-0.10%',
#   'Volume': '61,513'},
#  {'No.': '19',
#   'Ticker': 'TGNA',
#   'Perf Week': '-5.76%',
#   'Perf Month': '13.34%',
#   'Perf Quart': '9.52%',
#   'Perf Half': '-0.30%',
#   'Perf Year': '75.44%',
#   'Perf YTD': '44.37%',
#   'Volatility W': '2.53%',
#   'Volatility M': '3.47%',
#   'Recom': '2.10',
#   'Avg Volume': '1.40M',
#   'Rel Volume': '0.83',
#   'Price': '20.10',
#   'Change': '-0.20%',
#   'Volume': '753,230'},
#  {'No.': '20',
#   'Ticker': 'CVA',
#   'Perf Week': '0.60%',
#   'Perf Month': '0.65%',
#   'Perf Quart': '13.86%',
#   'Perf Half': '45.08%',
#   'Perf Year': '154.53%',
#   'Perf YTD': '53.92%',
#   'Volatility W': '0.35%',
#   'Volatility M': '0.31%',
#   'Recom': '3.00',
#   'Avg Volume': '1.99M',
#   'Rel Volume': '0.49',
#   'Price': '20.13',
#   'Change': '-0.41%',
#   'Volume': '636,206'},
#  {'No.': '21',
#   'Ticker': 'MNRL',
#   'Perf Week': '1.03%',
#   'Perf Month': '4.91%',
#   'Perf Quart': '-0.34%',
#   'Perf Half': '32.30%',
#   'Perf Year': '127.61%',
#   'Perf YTD': '88.88%',
#   'Volatility W': '3.62%',
#   'Volatility M': '3.21%',
#   'Recom': '1.80',
#   'Avg Volume': '214.33K',
#   'Rel Volume': '1.18',
#   'Price': '20.35',
#   'Change': '-0.78%',
#   'Volume': '164,629'},
#  {'No.': '22',
#   'Ticker': 'HOLI',
#   'Perf Week': '-0.59%',
#   'Perf Month': '4.51%',
#   'Perf Quart': '40.26%',
#   'Perf Half': '63.43%',
#   'Perf Year': '82.45%',
#   'Perf YTD': '38.73%',
#   'Volatility W': '1.85%',
#   'Volatility M': '2.45%',
#   'Recom': '1.60',
#   'Avg Volume': '368.59K',
#   'Rel Volume': '0.84',
#   'Price': '20.53',
#   'Change': '0.74%',
#   'Volume': '201,724'},
#  {'No.': '23',
#   'Ticker': 'ARCC',
#   'Perf Week': '1.68%',
#   'Perf Month': '2.03%',
#   'Perf Quart': '3.15%',
#   'Perf Half': '8.07%',
#   'Perf Year': '43.86%',
#   'Perf YTD': '22.14%',
#   'Volatility W': '1.38%',
#   'Volatility M': '1.18%',
#   'Recom': '1.70',
#   'Avg Volume': '2.13M',
#   'Rel Volume': '0.62',
#   'Price': '20.73',
#   'Change': '0.48%',
#   'Volume': '861,960'},
#  {'No.': '24',
#   'Ticker': 'CSTR',
#   'Perf Week': '-2.73%',
#   'Perf Month': '-0.33%',
#   'Perf Quart': '5.17%',
#   'Perf Half': '17.96%',
#   'Perf Year': '116.31%',
#   'Perf YTD': '44.75%',
#   'Volatility W': '2.74%',
#   'Volatility M': '1.67%',
#   'Recom': '2.00',
#   'Avg Volume': '51.94K',
#   'Rel Volume': '2.00',
#   'Price': '21.35',
#   'Change': '0.00%',
#   'Volume': '67,327'},
#  {'No.': '25',
#   'Ticker': 'EQT',
#   'Perf Week': '-3.85%',
#   'Perf Month': '8.32%',
#   'Perf Quart': '3.87%',
#   'Perf Half': '16.42%',
#   'Perf Year': '68.74%',
#   'Perf YTD': '69.00%',
#   'Volatility W': '4.17%',
#   'Volatility M': '4.72%',
#   'Recom': '2.10',
#   'Avg Volume': '7.72M',
#   'Rel Volume': '2.44',
#   'Price': '21.45',
#   'Change': '-0.12%',
#   'Volume': '12,216,744'},
#  {'No.': '26',
#   'Ticker': 'CCRN',
#   'Perf Week': '-0.28%',
#   'Perf Month': '1.55%',
#   'Perf Quart': '36.76%',
#   'Perf Half': '73.89%',
#   'Perf Year': '249.19%',
#   'Perf YTD': '143.29%',
#   'Volatility W': '3.79%',
#   'Volatility M': '3.89%',
#   'Recom': '2.50',
#   'Avg Volume': '274.64K',
#   'Rel Volume': '2.68',
#   'Price': '21.70',
#   'Change': '0.54%',
#   'Volume': '477,508'},
#  {'No.': '27',
#   'Ticker': 'DSPG',
#   'Perf Week': '0.00%',
#   'Perf Month': '-0.32%',
#   'Perf Quart': '45.69%',
#   'Perf Half': '47.86%',
#   'Perf Year': '66.39%',
#   'Perf YTD': '31.28%',
#   'Volatility W': '0.40%',
#   'Volatility M': '0.43%',
#   'Recom': '2.80',
#   'Avg Volume': '482.62K',
#   'Rel Volume': '0.17',
#   'Price': '21.83',
#   'Change': '0.25%',
#   'Volume': '53,673'},
#  {'No.': '28',
#   'Ticker': 'VLRS',
#   'Perf Week': '-2.30%',
#   'Perf Month': '11.79%',
#   'Perf Quart': '9.19%',
#   'Perf Half': '45.97%',
#   'Perf Year': '192.72%',
#   'Perf YTD': '77.94%',
#   'Volatility W': '3.47%',
#   'Volatility M': '3.21%',
#   'Recom': '2.00',
#   'Avg Volume': '732.58K',
#   'Rel Volume': '0.93',
#   'Price': '21.97',
#   'Change': '-0.59%',
#   'Volume': '440,810'},
#  {'No.': '29',
#   'Ticker': 'APA',
#   'Perf Week': '-5.16%',
#   'Perf Month': '11.13%',
#   'Perf Quart': '7.40%',
#   'Perf Half': '23.52%',
#   'Perf Year': '126.49%',
#   'Perf YTD': '55.46%',
#   'Volatility W': '5.55%',
#   'Volatility M': '4.80%',
#   'Recom': '2.40',
#   'Avg Volume': '8.41M',
#   'Rel Volume': '1.35',
#   'Price': '22.11',
#   'Change': '0.23%',
#   'Volume': '7,347,469'},
#  {'No.': '30',
#   'Ticker': 'VNOM',
#   'Perf Week': '5.61%',
#   'Perf Month': '19.64%',
#   'Perf Quart': '26.00%',
#   'Perf Half': '58.30%',
#   'Perf Year': '207.91%',
#   'Perf YTD': '97.68%',
#   'Volatility W': '5.31%',
#   'Volatility M': '4.18%',
#   'Recom': '1.80',
#   'Avg Volume': '382.13K',
#   'Rel Volume': '1.23',
#   'Price': '22.89',
#   'Change': '-0.35%',
#   'Volume': '304,272'},
#  {'No.': '31',
#   'Ticker': 'ESI',
#   'Perf Week': '-2.23%',
#   'Perf Month': '-1.33%',
#   'Perf Quart': '-2.28%',
#   'Perf Half': '15.96%',
#   'Perf Year': '103.19%',
#   'Perf YTD': '25.83%',
#   'Volatility W': '2.74%',
#   'Volatility M': '2.69%',
#   'Recom': '2.10',
#   'Avg Volume': '1.29M',
#   'Rel Volume': '0.75',
#   'Price': '22.94',
#   'Change': '2.82%',
#   'Volume': '625,180'},
#  {'No.': '32',
#   'Ticker': 'FFIC',
#   'Perf Week': '1.62%',
#   'Perf Month': '2.83%',
#   'Perf Quart': '12.90%',
#   'Perf Half': '10.23%',
#   'Perf Year': '109.16%',
#   'Perf YTD': '39.90%',
#   'Volatility W': '2.29%',
#   'Volatility M': '2.29%',
#   'Recom': '2.50',
#   'Avg Volume': '109.53K',
#   'Rel Volume': '0.85',
#   'Price': '23.25',
#   'Change': '-0.13%',
#   'Volume': '60,801'},
#  {'No.': '33',
#   'Ticker': 'WBT',
#   'Perf Week': '0.04%',
#   'Perf Month': '0.13%',
#   'Perf Quart': '-5.68%',
#   'Perf Half': '48.90%',
#   'Perf Year': '263.64%',
#   'Perf YTD': '78.79%',
#   'Volatility W': '0.73%',
#   'Volatility M': '0.48%',
#   'Recom': '3.00',
#   'Avg Volume': '1.83M',
#   'Rel Volume': '0.39',
#   'Price': '23.55',
#   'Change': '-0.23%',
#   'Volume': '464,904'},
#  {'No.': '34',
#   'Ticker': 'GTN',
#   'Perf Week': '-1.05%',
#   'Perf Month': '2.84%',
#   'Perf Quart': '1.69%',
#   'Perf Half': '23.55%',
#   'Perf Year': '73.18%',
#   'Perf YTD': '31.36%',
#   'Volatility W': '2.62%',
#   'Volatility M': '2.97%',
#   'Recom': '1.40',
#   'Avg Volume': '493.51K',
#   'Rel Volume': '0.46',
#   'Price': '23.66',
#   'Change': '0.68%',
#   'Volume': '146,755'},
#  {'No.': '35',
#   'Ticker': 'ORI',
#   'Perf Week': '1.25%',
#   'Perf Month': '-2.23%',
#   'Perf Quart': '0.31%',
#   'Perf Half': '9.42%',
#   'Perf Year': '75.58%',
#   'Perf YTD': '33.98%',
#   'Volatility W': '2.30%',
#   'Volatility M': '1.99%',
#   'Recom': '2.30',
#   'Avg Volume': '1.95M',
#   'Rel Volume': '0.57',
#   'Price': '23.70',
#   'Change': '0.55%',
#   'Volume': '727,745'},
#  {'No.': '36',
#   'Ticker': 'ALEX',
#   'Perf Week': '4.14%',
#   'Perf Month': '14.25%',
#   'Perf Quart': '31.91%',
#   'Perf Half': '40.02%',
#   'Perf Year': '103.71%',
#   'Perf YTD': '40.51%',
#   'Volatility W': '2.46%',
#   'Volatility M': '2.62%',
#   'Recom': '1.70',
#   'Avg Volume': '395.85K',
#   'Rel Volume': '0.44',
#   'Price': '23.90',
#   'Change': '-1.01%',
#   'Volume': '113,868'},
#  {'No.': '37',
#   'Ticker': 'BFST',
#   'Perf Week': '-0.17%',
#   'Perf Month': '0.13%',
#   'Perf Quart': '3.78%',
#   'Perf Half': '-1.40%',
#   'Perf Year': '54.00%',
#   'Perf YTD': '17.24%',
#   'Volatility W': '2.38%',
#   'Volatility M': '2.74%',
#   'Recom': '1.80',
#   'Avg Volume': '39.35K',
#   'Rel Volume': '4.25',
#   'Price': '23.99',
#   'Change': '0.50%',
#   'Volume': '108,444'},
#  {'No.': '38',
#   'Ticker': 'RRC',
#   'Perf Week': '9.41%',
#   'Perf Month': '46.30%',
#   'Perf Quart': '55.67%',
#   'Perf Half': '137.07%',
#   'Perf Year': '273.85%',
#   'Perf YTD': '262.69%',
#   'Volatility W': '5.76%',
#   'Volatility M': '5.18%',
#   'Recom': '2.80',
#   'Avg Volume': '4.98M',
#   'Rel Volume': '1.44',
#   'Price': '24.02',
#   'Change': '-1.15%',
#   'Volume': '4,670,419'},
#  {'No.': '39',
#   'Ticker': 'EVRI',
#   'Perf Week': '3.49%',
#   'Perf Month': '14.40%',
#   'Perf Quart': '4.92%',
#   'Perf Half': '75.41%',
#   'Perf Year': '201.99%',
#   'Perf YTD': '86.97%',
#   'Volatility W': '4.57%',
#   'Volatility M': '3.93%',
#   'Recom': '1.50',
#   'Avg Volume': '850.39K',
#   'Rel Volume': '1.41',
#   'Price': '24.22',
#   'Change': '-6.20%',
#   'Volume': '779,097'},
#  {'No.': '40',
#   'Ticker': 'ARD',
#   'Perf Week': '-1.35%',
#   'Perf Month': '-2.45%',
#   'Perf Quart': '1.33%',
#   'Perf Half': '-3.89%',
#   'Perf Year': '80.53%',
#   'Perf YTD': '47.38%',
#   'Volatility W': '2.38%',
#   'Volatility M': '2.25%',
#   'Recom': '2.10',
#   'Avg Volume': '148.79K',
#   'Rel Volume': '0.80',
#   'Price': '24.25',
#   'Change': '0.54%',
#   'Volume': '77,072'},
#  {'No.': '41',
#   'Ticker': 'PFS',
#   'Perf Week': '2.32%',
#   'Perf Month': '10.27%',
#   'Perf Quart': '9.72%',
#   'Perf Half': '6.78%',
#   'Perf Year': '90.42%',
#   'Perf YTD': '35.08%',
#   'Volatility W': '2.16%',
#   'Volatility M': '2.29%',
#   'Recom': '2.70',
#   'Avg Volume': '237.06K',
#   'Rel Volume': '0.44',
#   'Price': '24.33',
#   'Change': '0.29%',
#   'Volume': '68,260'},
#  {'No.': '42',
#   'Ticker': 'GDP',
#   'Perf Week': '12.09%',
#   'Perf Month': '26.10%',
#   'Perf Quart': '73.10%',
#   'Perf Half': '158.14%',
#   'Perf Year': '202.40%',
#   'Perf YTD': '149.95%',
#   'Volatility W': '8.05%',
#   'Volatility M': '7.28%',
#   'Recom': '2.00',
#   'Avg Volume': '84.16K',
#   'Rel Volume': '2.31',
#   'Price': '24.47',
#   'Change': '-2.97%',
#   'Volume': '126,106'},
#  {'No.': '43',
#   'Ticker': 'SBLK',
#   'Perf Week': '0.09%',
#   'Perf Month': '-2.34%',
#   'Perf Quart': '13.59%',
#   'Perf Half': '62.95%',
#   'Perf Year': '217.50%',
#   'Perf YTD': '165.01%',
#   'Volatility W': '6.74%',
#   'Volatility M': '5.77%',
#   'Recom': '1.60',
#   'Avg Volume': '1.96M',
#   'Rel Volume': '1.29',
#   'Price': '24.72',
#   'Change': '5.64%',
#   'Volume': '1,639,480'},
#  {'No.': '44',
#   'Ticker': 'BOX',
#   'Perf Week': '-2.54%',
#   'Perf Month': '-4.36%',
#   'Perf Quart': '-6.64%',
#   'Perf Half': '1.99%',
#   'Perf Year': '43.80%',
#   'Perf YTD': '36.23%',
#   'Volatility W': '4.08%',
#   'Volatility M': '3.77%',
#   'Recom': '2.30',
#   'Avg Volume': '2.42M',
#   'Rel Volume': '0.61',
#   'Price': '24.86',
#   'Change': '1.12%',
#   'Volume': '957,249'},
#  {'No.': '45',
#   'Ticker': 'TROX',
#   'Perf Week': '-1.88%',
#   'Perf Month': '19.40%',
#   'Perf Quart': '14.93%',
#   'Perf Half': '19.86%',
#   'Perf Year': '197.70%',
#   'Perf YTD': '67.99%',
#   'Volatility W': '2.72%',
#   'Volatility M': '4.68%',
#   'Recom': '2.20',
#   'Avg Volume': '2.04M',
#   'Rel Volume': '0.79',
#   'Price': '24.90',
#   'Change': '1.38%',
#   'Volume': '1,046,560'},
#  {'No.': '46',
#   'Ticker': 'OPRT',
#   'Perf Week': '-1.02%',
#   'Perf Month': '-1.05%',
#   'Perf Quart': '24.95%',
#   'Perf Half': '17.31%',
#   'Perf Year': '89.67%',
#   'Perf YTD': '30.82%',
#   'Volatility W': '3.98%',
#   'Volatility M': '3.84%',
#   'Recom': '1.80',
#   'Avg Volume': '57.40K',
#   'Rel Volume': '3.15',
#   'Price': '25.18',
#   'Change': '-0.61%',
#   'Volume': '117,332'},
#  {'No.': '47',
#   'Ticker': 'SWCH',
#   'Perf Week': '-0.16%',
#   'Perf Month': '-2.39%',
#   'Perf Quart': '19.05%',
#   'Perf Half': '47.32%',
#   'Perf Year': '62.24%',
#   'Perf YTD': '54.61%',
#   'Volatility W': '2.42%',
#   'Volatility M': '2.10%',
#   'Recom': '1.80',
#   'Avg Volume': '2.08M',
#   'Rel Volume': '0.28',
#   'Price': '25.33',
#   'Change': '0.06%',
#   'Volume': '379,772'},
#  {'No.': '48',
#   'Ticker': 'TECK',
#   'Perf Week': '2.50%',
#   'Perf Month': '8.12%',
#   'Perf Quart': '16.52%',
#   'Perf Half': '27.95%',
#   'Perf Year': '81.07%',
#   'Perf YTD': '42.26%',
#   'Volatility W': '3.24%',
#   'Volatility M': '4.20%',
#   'Recom': '2.20',
#   'Avg Volume': '4.69M',
#   'Rel Volume': '0.74',
#   'Price': '25.64',
#   'Change': '-0.72%',
#   'Volume': '2,253,591'},
#  {'No.': '49',
#   'Ticker': 'IHRT',
#   'Perf Week': '2.70%',
#   'Perf Month': '4.02%',
#   'Perf Quart': '-1.15%',
#   'Perf Half': '44.94%',
#   'Perf Year': '216.24%',
#   'Perf YTD': '99.54%',
#   'Volatility W': '3.00%',
#   'Volatility M': '3.35%',
#   'Recom': '1.70',
#   'Avg Volume': '897.85K',
#   'Rel Volume': '1.16',
#   'Price': '26.19',
#   'Change': '1.12%',
#   'Volume': '674,321'},
#  {'No.': '50',
#   'Ticker': 'SKIN',
#   'Perf Week': '-6.29%',
#   'Perf Month': '-2.91%',
#   'Perf Quart': '38.12%',
#   'Perf Half': '141.65%',
#   'Perf Year': '-',
#   'Perf YTD': '130.33%',
#   'Volatility W': '5.32%',
#   'Volatility M': '5.79%',
#   'Recom': '1.70',
#   'Avg Volume': '2.52M',
#   'Rel Volume': '0.43',
#   'Price': '26.23',
#   'Change': '0.69%',
#   'Volume': '703,338'},
#  {'No.': '51',
#   'Ticker': 'KE',
#   'Perf Week': '-1.41%',
#   'Perf Month': '9.97%',
#   'Perf Quart': '26.32%',
#   'Perf Half': '2.43%',
#   'Perf Year': '131.82%',
#   'Perf YTD': '66.29%',
#   'Volatility W': '3.84%',
#   'Volatility M': '3.32%',
#   'Recom': '1.00',
#   'Avg Volume': '80.39K',
#   'Rel Volume': '1.32',
#   'Price': '27.20',
#   'Change': '2.29%',
#   'Volume': '68,664'},
#  {'No.': '52',
#   'Ticker': 'MUR',
#   'Perf Week': '13.72%',
#   'Perf Month': '27.26%',
#   'Perf Quart': '20.51%',
#   'Perf Half': '65.35%',
#   'Perf Year': '222.99%',
#   'Perf YTD': '128.76%',
#   'Volatility W': '4.14%',
#   'Volatility M': '4.76%',
#   'Recom': '2.80',
#   'Avg Volume': '2.09M',
#   'Rel Volume': '1.30',
#   'Price': '27.20',
#   'Change': '-1.73%',
#   'Volume': '1,765,115'},
#  {'No.': '53',
#   'Ticker': 'WMB',
#   'Perf Week': '4.99%',
#   'Perf Month': '8.88%',
#   'Perf Quart': '3.48%',
#   'Perf Half': '15.02%',
#   'Perf Year': '43.22%',
#   'Perf YTD': '36.36%',
#   'Volatility W': '2.79%',
#   'Volatility M': '2.03%',
#   'Recom': '1.90',
#   'Avg Volume': '7.40M',
#   'Rel Volume': '1.42',
#   'Price': '27.21',
#   'Change': '-0.48%',
#   'Volume': '6,806,121'},
#  {'No.': '54',
#   'Ticker': 'XENT',
#   'Perf Week': '0.41%',
#   'Perf Month': '-1.31%',
#   'Perf Quart': '44.30%',
#   'Perf Half': '29.34%',
#   'Perf Year': '68.00%',
#   'Perf YTD': '18.78%',
#   'Volatility W': '0.62%',
#   'Volatility M': '0.79%',
#   'Recom': '3.10',
#   'Avg Volume': '848.36K',
#   'Rel Volume': '2.50',
#   'Price': '27.24',
#   'Change': '0.13%',
#   'Volume': '1,377,134'},
#  {'No.': '55',
#   'Ticker': 'ACBI',
#   'Perf Week': '4.99%',
#   'Perf Month': '12.75%',
#   'Perf Quart': '10.47%',
#   'Perf Half': '11.41%',
#   'Perf Year': '127.56%',
#   'Perf YTD': '71.67%',
#   'Volatility W': '3.33%',
#   'Volatility M': '2.75%',
#   'Recom': '2.20',
#   'Avg Volume': '147.63K',
#   'Rel Volume': '0.68',
#   'Price': '27.44',
#   'Change': '0.40%',
#   'Volume': '65,269'},
#  {'No.': '56',
#   'Ticker': 'IGT',
#   'Perf Week': '6.37%',
#   'Perf Month': '29.04%',
#   'Perf Quart': '18.20%',
#   'Perf Half': '61.22%',
#   'Perf Year': '138.23%',
#   'Perf YTD': '63.70%',
#   'Volatility W': '4.22%',
#   'Volatility M': '4.67%',
#   'Recom': '2.00',
#   'Avg Volume': '2.06M',
#   'Rel Volume': '1.14',
#   'Price': '27.57',
#   'Change': '-0.58%',
#   'Volume': '1,531,738'},
#  {'No.': '57',
#   'Ticker': 'SCU',
#   'Perf Week': '1.22%',
#   'Perf Month': '0.00%',
#   'Perf Quart': '15.95%',
#   'Perf Half': '27.91%',
#   'Perf Year': '145.98%',
#   'Perf YTD': '85.13%',
#   'Volatility W': '2.45%',
#   'Volatility M': '2.67%',
#   'Recom': '2.00',
#   'Avg Volume': '162.98K',
#   'Rel Volume': '0.56',
#   'Price': '28.21',
#   'Change': '0.25%',
#   'Volume': '59,027'},
#  {'No.': '58',
#   'Ticker': 'MPLX',
#   'Perf Week': '1.00%',
#   'Perf Month': '0.82%',
#   'Perf Quart': '-1.51%',
#   'Perf Half': '12.46%',
#   'Perf Year': '89.14%',
#   'Perf YTD': '35.94%',
#   'Volatility W': '2.35%',
#   'Volatility M': '2.15%',
#   'Recom': '2.10',
#   'Avg Volume': '1.92M',
#   'Rel Volume': '0.85',
#   'Price': '29.14',
#   'Change': '-1.00%',
#   'Volume': '1,055,830'},
#  {'No.': '59',
#   'Ticker': 'SBOW',
#   'Perf Week': '22.42%',
#   'Perf Month': '52.91%',
#   'Perf Quart': '25.16%',
#   'Perf Half': '271.55%',
#   'Perf Year': '658.31%',
#   'Perf YTD': '458.38%',
#   'Volatility W': '9.62%',
#   'Volatility M': '7.67%',
#   'Recom': '2.50',
#   'Avg Volume': '144.30K',
#   'Rel Volume': '2.27',
#   'Price': '29.19',
#   'Change': '-1.55%',
#   'Volume': '213,041'},
#  {'No.': '60',
#   'Ticker': 'PPC',
#   'Perf Week': '1.66%',
#   'Perf Month': '4.34%',
#   'Perf Quart': '34.11%',
#   'Perf Half': '20.90%',
#   'Perf Year': '88.86%',
#   'Perf YTD': '49.57%',
#   'Volatility W': '2.08%',
#   'Volatility M': '1.55%',
#   'Recom': '2.20',
#   'Avg Volume': '881.49K',
#   'Rel Volume': '0.47',
#   'Price': '29.31',
#   'Change': '-0.07%',
#   'Volume': '270,381'},
#  {'No.': '61',
#   'Ticker': 'LBTYK',
#   'Perf Week': '-3.79%',
#   'Perf Month': '-1.10%',
#   'Perf Quart': '10.69%',
#   'Perf Half': '11.63%',
#   'Perf Year': '46.48%',
#   'Perf YTD': '22.20%',
#   'Volatility W': '3.30%',
#   'Volatility M': '2.78%',
#   'Recom': '2.00',
#   'Avg Volume': '2.46M',
#   'Rel Volume': '0.96',
#   'Price': '29.73',
#   'Change': '2.86%',
#   'Volume': '1,533,251'},
#  {'No.': '62',
#   'Ticker': 'LBTYA',
#   'Perf Week': '-3.42%',
#   'Perf Month': '-0.07%',
#   'Perf Quart': '11.25%',
#   'Perf Half': '11.29%',
#   'Perf Year': '44.48%',
#   'Perf YTD': '20.02%',
#   'Volatility W': '3.25%',
#   'Volatility M': '2.57%',
#   'Recom': '2.20',
#   'Avg Volume': '1.43M',
#   'Rel Volume': '0.74',
#   'Price': '29.84',
#   'Change': '2.67%',
#   'Volume': '691,193'},
#  {'No.': '63',
#   'Ticker': 'ELF',
#   'Perf Week': '-2.97%',
#   'Perf Month': '-6.28%',
#   'Perf Quart': '10.65%',
#   'Perf Half': '7.70%',
#   'Perf Year': '55.12%',
#   'Perf YTD': '15.52%',
#   'Volatility W': '3.06%',
#   'Volatility M': '2.80%',
#   'Recom': '1.90',
#   'Avg Volume': '467.51K',
#   'Rel Volume': '0.41',
#   'Price': '30.07',
#   'Change': '3.33%',
#   'Volume': '123,462'},
#  {'No.': '64',
#   'Ticker': 'ITMR',
#   'Perf Week': '-0.17%',
#   'Perf Month': '45.75%',
#   'Perf Quart': '27.86%',
#   'Perf Half': '25.13%',
#   'Perf Year': '48.92%',
#   'Perf YTD': '52.06%',
#   'Volatility W': '0.42%',
#   'Volatility M': '1.28%',
#   'Recom': '1.70',
#   'Avg Volume': '154.18K',
#   'Rel Volume': '1.56',
#   'Price': '30.23',
#   'Change': '0.10%',
#   'Volume': '156,583'},
#  {'No.': '65',
#   'Ticker': 'PVAC',
#   'Perf Week': '35.40%',
#   'Perf Month': '59.21%',
#   'Perf Quart': '43.26%',
#   'Perf Half': '134.88%',
#   'Perf Year': '226.79%',
#   'Perf YTD': '218.42%',
#   'Volatility W': '8.90%',
#   'Volatility M': '6.25%',
#   'Recom': '2.00',
#   'Avg Volume': '347.52K',
#   'Rel Volume': '2.66',
#   'Price': '30.37',
#   'Change': '-6.03%',
#   'Volume': '599,670'},
#  {'No.': '66',
#   'Ticker': 'DCP',
#   'Perf Week': '7.04%',
#   'Perf Month': '8.50%',
#   'Perf Quart': '-1.85%',
#   'Perf Half': '36.00%',
#   'Perf Year': '169.94%',
#   'Perf YTD': '63.39%',
#   'Volatility W': '3.68%',
#   'Volatility M': '4.17%',
#   'Recom': '2.50',
#   'Avg Volume': '564.21K',
#   'Rel Volume': '1.32',
#   'Price': '30.89',
#   'Change': '2.08%',
#   'Volume': '484,736'},
#  {'No.': '67',
#   'Ticker': 'PECO',
#   'Perf Week': '2.87%',
#   'Perf Month': '3.69%',
#   'Perf Quart': '-',
#   'Perf Half': '-',
#   'Perf Year': '-',
#   'Perf YTD': '12.22%',
#   'Volatility W': '2.42%',
#   'Volatility M': '2.58%',
#   'Recom': '2.10',
#   'Avg Volume': '474.27K',
#   'Rel Volume': '0.54',
#   'Price': '31.18',
#   'Change': '-0.16%',
#   'Volume': '164,841'},
#  {'No.': '68',
#   'Ticker': 'VVV',
#   'Perf Week': '-1.82%',
#   'Perf Month': '3.59%',
#   'Perf Quart': '-0.81%',
#   'Perf Half': '20.36%',
#   'Perf Year': '62.27%',
#   'Perf YTD': '37.17%',
#   'Volatility W': '2.21%',
#   'Volatility M': '1.96%',
#   'Recom': '1.90',
#   'Avg Volume': '973.46K',
#   'Rel Volume': '0.66',
#   'Price': '31.48',
#   'Change': '-0.82%',
#   'Volume': '420,277'},
#  {'No.': '69',
#   'Ticker': 'PBA',
#   'Perf Week': '1.10%',
#   'Perf Month': '3.49%',
#   'Perf Quart': '1.73%',
#   'Perf Half': '9.72%',
#   'Perf Year': '50.61%',
#   'Perf YTD': '36.48%',
#   'Volatility W': '2.01%',
#   'Volatility M': '1.61%',
#   'Recom': '2.00',
#   'Avg Volume': '882.95K',
#   'Rel Volume': '1.22',
#   'Price': '31.78',
#   'Change': '-1.56%',
#   'Volume': '696,850'},
#  {'No.': '70',
#   'Ticker': 'WSC',
#   'Perf Week': '-2.31%',
#   'Perf Month': '7.14%',
#   'Perf Quart': '16.01%',
#   'Perf Half': '8.50%',
#   'Perf Year': '81.28%',
#   'Perf YTD': '36.69%',
#   'Volatility W': '3.31%',
#   'Volatility M': '2.87%',
#   'Recom': '1.60',
#   'Avg Volume': '1.94M',
#   'Rel Volume': '0.37',
#   'Price': '32.16',
#   'Change': '1.55%',
#   'Volume': '464,285'},
#  {'No.': '71',
#   'Ticker': 'OXY',
#   'Perf Week': '5.37%',
#   'Perf Month': '19.68%',
#   'Perf Quart': '4.26%',
#   'Perf Half': '25.48%',
#   'Perf Year': '222.29%',
#   'Perf YTD': '83.77%',
#   'Volatility W': '3.78%',
#   'Volatility M': '4.14%',
#   'Recom': '2.70',
#   'Avg Volume': '16.48M',
#   'Rel Volume': '1.82',
#   'Price': '32.66',
#   'Change': '2.67%',
#   'Volume': '19,475,848'},
#  {'No.': '72',
#   'Ticker': 'RYAN',
#   'Perf Week': '-2.78%',
#   'Perf Month': '-2.37%',
#   'Perf Quart': '-',
#   'Perf Half': '-',
#   'Perf Year': '-',
#   'Perf YTD': '19.60%',
#   'Volatility W': '3.63%',
#   'Volatility M': '4.07%',
#   'Recom': '2.20',
#   'Avg Volume': '1.06M',
#   'Rel Volume': '0.46',
#   'Price': '33.20',
#   'Change': '0.94%',
#   'Volume': '315,289'},
#  {'No.': '73',
#   'Ticker': 'IMO',
#   'Perf Week': '7.61%',
#   'Perf Month': '20.72%',
#   'Perf Quart': '10.71%',
#   'Perf Half': '32.25%',
#   'Perf Year': '183.30%',
#   'Perf YTD': '73.88%',
#   'Volatility W': '2.86%',
#   'Volatility M': '3.11%',
#   'Recom': '3.30',
#   'Avg Volume': '432.58K',
#   'Rel Volume': '0.56',
#   'Price': '33.28',
#   'Change': '0.57%',
#   'Volume': '156,739'},
#  {'No.': '74',
#   'Ticker': 'CBZ',
#   'Perf Week': '1.03%',
#   'Perf Month': '-3.22%',
#   'Perf Quart': '3.22%',
#   'Perf Half': '0.00%',
#   'Perf Year': '42.49%',
#   'Perf YTD': '25.40%',
#   'Volatility W': '2.10%',
#   'Volatility M': '2.07%',
#   'Recom': '1.30',
#   'Avg Volume': '147.70K',
#   'Rel Volume': '0.63',
#   'Price': '33.58',
#   'Change': '0.63%',
#   'Volume': '60,819'},
#  {'No.': '75',
#   'Ticker': 'DCOM',
#   'Perf Week': '2.58%',
#   'Perf Month': '2.55%',
#   'Perf Quart': '4.61%',
#   'Perf Half': '6.21%',
#   'Perf Year': '88.94%',
#   'Perf YTD': '39.95%',
#   'Volatility W': '2.61%',
#   'Volatility M': '2.94%',
#   'Recom': '1.80',
#   'Avg Volume': '174.19K',
#   'Rel Volume': '0.53',
#   'Price': '34.03',
#   'Change': '0.56%',
#   'Volume': '59,764'},
#  {'No.': '76',
#   'Ticker': 'TIXT',
#   'Perf Week': '-4.86%',
#   'Perf Month': '-0.49%',
#   'Perf Quart': '8.70%',
#   'Perf Half': '22.00%',
#   'Perf Year': '-',
#   'Perf YTD': '13.45%',
#   'Volatility W': '2.93%',
#   'Volatility M': '3.77%',
#   'Recom': '-',
#   'Avg Volume': '272.31K',
#   'Rel Volume': '0.58',
#   'Price': '34.36',
#   'Change': '-0.38%',
#   'Volume': '102,571'},
#  {'No.': '77',
#   'Ticker': 'TGH',
#   'Perf Week': '-3.66%',
#   'Perf Month': '1.47%',
#   'Perf Quart': '6.69%',
#   'Perf Half': '19.05%',
#   'Perf Year': '132.86%',
#   'Perf YTD': '79.56%',
#   'Volatility W': '3.51%',
#   'Volatility M': '3.74%',
#   'Recom': '2.00',
#   'Avg Volume': '415.77K',
#   'Rel Volume': '0.80',
#   'Price': '35.58',
#   'Change': '3.31%',
#   'Volume': '216,545'},
#  {'No.': '78',
#   'Ticker': 'LRN',
#   'Perf Week': '-1.10%',
#   'Perf Month': '4.50%',
#   'Perf Quart': '25.64%',
#   'Perf Half': '9.23%',
#   'Perf Year': '34.52%',
#   'Perf YTD': '69.43%',
#   'Volatility W': '3.28%',
#   'Volatility M': '3.47%',
#   'Recom': '1.70',
#   'Avg Volume': '534.90K',
#   'Rel Volume': '0.42',
#   'Price': '36.30',
#   'Change': '0.92%',
#   'Volume': '144,650'},
#  {'No.': '79',
#   'Ticker': 'GFL',
#   'Perf Week': '-1.20%',
#   'Perf Month': '4.09%',
#   'Perf Quart': '15.30%',
#   'Perf Half': '4.71%',
#   'Perf Year': '64.38%',
#   'Perf YTD': '26.53%',
#   'Volatility W': '2.90%',
#   'Volatility M': '2.83%',
#   'Recom': '-',
#   'Avg Volume': '1.02M',
#   'Rel Volume': '1.06',
#   'Price': '37.53',
#   'Change': '1.64%',
#   'Volume': '701,438'},
#  {'No.': '80',
#   'Ticker': 'HEES',
#   'Perf Week': '-0.33%',
#   'Perf Month': '6.58%',
#   'Perf Quart': '15.58%',
#   'Perf Half': '-3.39%',
#   'Perf Year': '67.19%',
#   'Perf YTD': '22.21%',
#   'Volatility W': '3.67%',
#   'Volatility M': '3.85%',
#   'Recom': '1.50',
#   'Avg Volume': '197.40K',
#   'Rel Volume': '1.10',
#   'Price': '37.88',
#   'Change': '3.98%',
#   'Volume': '141,518'},
#  {'No.': '81',
#   'Ticker': 'SUN',
#   'Perf Week': '1.20%',
#   'Perf Month': '1.99%',
#   'Perf Quart': '0.26%',
#   'Perf Half': '16.07%',
#   'Perf Year': '55.04%',
#   'Perf YTD': '32.04%',
#   'Volatility W': '1.39%',
#   'Volatility M': '1.52%',
#   'Recom': '2.60',
#   'Avg Volume': '287.38K',
#   'Rel Volume': '2.08',
#   'Price': '38.04',
#   'Change': '0.11%',
#   'Volume': '387,169'},
#  {'No.': '82',
#   'Ticker': 'PINC',
#   'Perf Week': '-1.21%',
#   'Perf Month': '3.51%',
#   'Perf Quart': '8.21%',
#   'Perf Half': '12.66%',
#   'Perf Year': '15.97%',
#   'Perf YTD': '9.26%',
#   'Volatility W': '2.29%',
#   'Volatility M': '2.09%',
#   'Recom': '2.60',
#   'Avg Volume': '627.24K',
#   'Rel Volume': '0.61',
#   'Price': '38.52',
#   'Change': '0.44%',
#   'Volume': '248,889'},
#  {'No.': '83',
#   'Ticker': 'MOS',
#   'Perf Week': '3.88%',
#   'Perf Month': '18.01%',
#   'Perf Quart': '26.35%',
#   'Perf Half': '23.61%',
#   'Perf Year': '109.01%',
#   'Perf YTD': '66.32%',
#   'Volatility W': '3.34%',
#   'Volatility M': '3.41%',
#   'Recom': '2.20',
#   'Avg Volume': '3.71M',
#   'Rel Volume': '0.95',
#   'Price': '38.53',
#   'Change': '0.68%',
#   'Volume': '2,290,608'},
#  {'No.': '84',
#   'Ticker': 'JAMF',
#   'Perf Week': '-3.66%',
#   'Perf Month': '7.88%',
#   'Perf Quart': '12.35%',
#   'Perf Half': '4.83%',
#   'Perf Year': '12.06%',
#   'Perf YTD': '27.67%',
#   'Volatility W': '3.09%',
#   'Volatility M': '3.33%',
#   'Recom': '2.10',
#   'Avg Volume': '560.50K',
#   'Rel Volume': '0.79',
#   'Price': '39.30',
#   'Change': '2.88%',
#   'Volume': '289,069'},
#  {'No.': '85',
#   'Ticker': 'ENB',
#   'Perf Week': '0.07%',
#   'Perf Month': '1.51%',
#   'Perf Quart': '0.55%',
#   'Perf Half': '9.93%',
#   'Perf Year': '39.57%',
#   'Perf YTD': '26.35%',
#   'Volatility W': '1.50%',
#   'Volatility M': '1.32%',
#   'Recom': '2.30',
#   'Avg Volume': '3.37M',
#   'Rel Volume': '1.12',
#   'Price': '40.20',
#   'Change': '-0.54%',
#   'Volume': '2,442,433'},
#  {'No.': '86',
#   'Ticker': 'INOV',
#   'Perf Week': '-0.15%',
#   'Perf Month': '-0.64%',
#   'Perf Quart': '18.54%',
#   'Perf Half': '34.74%',
#   'Perf Year': '50.89%',
#   'Perf YTD': '122.01%',
#   'Volatility W': '0.50%',
#   'Volatility M': '0.57%',
#   'Recom': '2.60',
#   'Avg Volume': '1.06M',
#   'Rel Volume': '0.41',
#   'Price': '40.44',
#   'Change': '0.26%',
#   'Volume': '284,068'},
#  {'No.': '87',
#   'Ticker': 'AVTR',
#   'Perf Week': '-4.10%',
#   'Perf Month': '-0.96%',
#   'Perf Quart': '11.27%',
#   'Perf Half': '29.19%',
#   'Perf Year': '75.90%',
#   'Perf YTD': '43.09%',
#   'Volatility W': '3.87%',
#   'Volatility M': '2.64%',
#   'Recom': '1.60',
#   'Avg Volume': '3.72M',
#   'Rel Volume': '0.61',
#   'Price': '40.51',
#   'Change': '0.57%',
#   'Volume': '1,467,696'},
#  {'No.': '88',
#   'Ticker': 'MTDR',
#   'Perf Week': '11.64%',
#   'Perf Month': '40.10%',
#   'Perf Quart': '18.30%',
#   'Perf Half': '67.47%',
#   'Perf Year': '388.06%',
#   'Perf YTD': '235.49%',
#   'Volatility W': '4.78%',
#   'Volatility M': '4.81%',
#   'Recom': '2.10',
#   'Avg Volume': '1.50M',
#   'Rel Volume': '1.60',
#   'Price': '40.53',
#   'Change': '0.17%',
#   'Volume': '1,565,211'},
#  {'No.': '89',
#   'Ticker': 'FSS',
#   'Perf Week': '1.36%',
#   'Perf Month': '-1.80%',
#   'Perf Quart': '3.38%',
#   'Perf Half': '1.94%',
#   'Perf Year': '35.82%',
#   'Perf YTD': '21.74%',
#   'Volatility W': '2.61%',
#   'Volatility M': '2.27%',
#   'Recom': '1.50',
#   'Avg Volume': '173.98K',
#   'Rel Volume': '0.62',
#   'Price': '40.78',
#   'Change': '0.99%',
#   'Volume': '70,252'},
#  {'No.': '90',
#   'Ticker': 'CRC',
#   'Perf Week': '1.36%',
#   'Perf Month': '11.21%',
#   'Perf Quart': '43.92%',
#   'Perf Half': '69.82%',
#   'Perf Year': '-',
#   'Perf YTD': '73.63%',
#   'Volatility W': '3.60%',
#   'Volatility M': '4.23%',
#   'Recom': '2.00',
#   'Avg Volume': '869.48K',
#   'Rel Volume': '1.32',
#   'Price': '40.99',
#   'Change': '0.06%',
#   'Volume': '745,647'},
#  {'No.': '91',
#   'Ticker': 'CQP',
#   'Perf Week': '-0.19%',
#   'Perf Month': '-2.83%',
#   'Perf Quart': '-8.29%',
#   'Perf Half': '-3.91%',
#   'Perf Year': '20.54%',
#   'Perf YTD': '17.05%',
#   'Volatility W': '2.94%',
#   'Volatility M': '3.25%',
#   'Recom': '3.10',
#   'Avg Volume': '143.52K',
#   'Rel Volume': '0.80',
#   'Price': '41.22',
#   'Change': '-0.10%',
#   'Volume': '74,392'},
#  {'No.': '92',
#   'Ticker': 'SHOO',
#   'Perf Week': '-3.31%',
#   'Perf Month': '1.11%',
#   'Perf Quart': '-3.90%',
#   'Perf Half': '6.13%',
#   'Perf Year': '101.13%',
#   'Perf YTD': '15.77%',
#   'Volatility W': '3.37%',
#   'Volatility M': '2.84%',
#   'Recom': '2.60',
#   'Avg Volume': '724.82K',
#   'Rel Volume': '0.41',
#   'Price': '41.41',
#   'Change': '1.27%',
#   'Volume': '192,261'},
#  {'No.': '93',
#   'Ticker': 'MAIN',
#   'Perf Week': '-0.91%',
#   'Perf Month': '-0.93%',
#   'Perf Quart': '-0.74%',
#   'Perf Half': '1.79%',
#   'Perf Year': '35.02%',
#   'Perf YTD': '28.70%',
#   'Volatility W': '1.36%',
#   'Volatility M': '1.24%',
#   'Recom': '2.30',
#   'Avg Volume': '250.51K',
#   'Rel Volume': '0.89',
#   'Price': '41.79',
#   'Change': '0.65%',
#   'Volume': '144,088'},
#  {'No.': '94',
#   'Ticker': 'FOXA',
#   'Perf Week': '3.39%',
#   'Perf Month': '11.60%',
#   'Perf Quart': '12.93%',
#   'Perf Half': '11.96%',
#   'Perf Year': '47.72%',
#   'Perf YTD': '42.45%',
#   'Volatility W': '2.27%',
#   'Volatility M': '2.68%',
#   'Recom': '2.40',
#   'Avg Volume': '2.50M',
#   'Rel Volume': '0.85',
#   'Price': '41.93',
#   'Change': '1.08%',
#   'Volume': '1,383,657'},
#  {'No.': '95',
#   'Ticker': 'SBR',
#   'Perf Week': '0.49%',
#   'Perf Month': '9.67%',
#   'Perf Quart': '6.80%',
#   'Perf Half': '38.73%',
#   'Perf Year': '47.62%',
#   'Perf YTD': '53.08%',
#   'Volatility W': '2.52%',
#   'Volatility M': '2.10%',
#   'Recom': '-',
#   'Avg Volume': '29.29K',
#   'Rel Volume': '3.64',
#   'Price': '43.62',
#   'Change': '0.98%',
#   'Volume': '69,228'},
#  {'No.': '96',
#   'Ticker': 'WMG',
#   'Perf Week': '0.89%',
#   'Perf Month': '15.41%',
#   'Perf Quart': '24.40%',
#   'Perf Half': '25.84%',
#   'Perf Year': '58.66%',
#   'Perf YTD': '16.90%',
#   'Volatility W': '4.81%',
#   'Volatility M': '3.95%',
#   'Recom': '2.40',
#   'Avg Volume': '802.79K',
#   'Rel Volume': '0.53',
#   'Price': '44.38',
#   'Change': '-0.06%',
#   'Volume': '274,254'},
#  {'No.': '97',
#   'Ticker': 'BCYC',
#   'Perf Week': '3.50%',
#   'Perf Month': '8.33%',
#   'Perf Quart': '37.81%',
#   'Perf Half': '46.22%',
#   'Perf Year': '126.15%',
#   'Perf YTD': '145.68%',
#   'Volatility W': '6.96%',
#   'Volatility M': '7.19%',
#   'Recom': '1.70',
#   'Avg Volume': '200.78K',
#   'Rel Volume': '0.93',
#   'Price': '44.55',
#   'Change': '1.02%',
#   'Volume': '121,857'},
#  {'No.': '98',
#   'Ticker': 'MGM',
#   'Perf Week': '-1.29%',
#   'Perf Month': '4.58%',
#   'Perf Quart': '7.90%',
#   'Perf Half': '7.20%',
#   'Perf Year': '105.49%',
#   'Perf YTD': '41.26%',
#   'Volatility W': '2.91%',
#   'Volatility M': '3.62%',
#   'Recom': '2.50',
#   'Avg Volume': '6.54M',
#   'Rel Volume': '1.29',
#   'Price': '44.85',
#   'Change': '0.75%',
#   'Volume': '5,458,842'},
#  {'No.': '99',
#   'Ticker': 'CSV',
#   'Perf Week': '-0.69%',
#   'Perf Month': '-7.35%',
#   'Perf Quart': '24.76%',
#   'Perf Half': '21.77%',
#   'Perf Year': '89.96%',
#   'Perf YTD': '42.53%',
#   'Volatility W': '2.26%',
#   'Volatility M': '2.43%',
#   'Recom': '1.50',
#   'Avg Volume': '126.32K',
#   'Rel Volume': '0.67',
#   'Price': '44.92',
#   'Change': '0.63%',
#   'Volume': '55,247'},
#  {'No.': '100',
#   'Ticker': 'DISH',
#   'Perf Week': '1.54%',
#   'Perf Month': '-0.31%',
#   'Perf Quart': '8.87%',
#   'Perf Half': '21.37%',
#   'Perf Year': '59.15%',
#   'Perf YTD': '40.48%',
#   'Volatility W': '2.87%',
#   'Volatility M': '2.83%',
#   'Recom': '2.40',
#   'Avg Volume': '1.85M',
#   'Rel Volume': '0.63',
#   'Price': '45.29',
#   'Change': '-0.31%',
#   'Volume': '761,252'},
#  {'No.': '101',
#   'Ticker': 'TPX',
#   'Perf Week': '-7.77%',
#   'Perf Month': '-0.37%',
#   'Perf Quart': '12.34%',
#   'Perf Half': '21.21%',
#   'Perf Year': '99.21%',
#   'Perf YTD': '68.89%',
#   'Volatility W': '2.92%',
#   'Volatility M': '2.49%',
#   'Recom': '2.10',
#   'Avg Volume': '1.80M',
#   'Rel Volume': '0.64',
#   'Price': '45.79',
#   'Change': '0.42%',
#   'Volume': '752,350'},
#  {'No.': '102',
#   'Ticker': 'ON',
#   'Perf Week': '-9.28%',
#   'Perf Month': '-1.12%',
#   'Perf Quart': '17.42%',
#   'Perf Half': '3.03%',
#   'Perf Year': '100.04%',
#   'Perf YTD': '37.15%',
#   'Volatility W': '2.86%',
#   'Volatility M': '2.57%',
#   'Recom': '2.10',
#   'Avg Volume': '5.62M',
#   'Rel Volume': '0.84',
#   'Price': '46.03',
#   'Change': '2.54%',
#   'Volume': '3,061,139'},
#  {'No.': '103',
#   'Ticker': 'HSII',
#   'Perf Week': '5.76%',
#   'Perf Month': '9.50%',
#   'Perf Quart': '12.70%',
#   'Perf Half': '26.94%',
#   'Perf Year': '140.32%',
#   'Perf YTD': '60.07%',
#   'Volatility W': '3.72%',
#   'Volatility M': '3.25%',
#   'Recom': '1.70',
#   'Avg Volume': '100.22K',
#   'Rel Volume': '1.00',
#   'Price': '46.60',
#   'Change': '-0.91%',
#   'Volume': '64,867'},
#  {'No.': '104',
#   'Ticker': 'PPD',
#   'Perf Week': '0.36%',
#   'Perf Month': '0.47%',
#   'Perf Quart': '1.87%',
#   'Perf Half': '20.40%',
#   'Perf Year': '31.68%',
#   'Perf YTD': '37.14%',
#   'Volatility W': '0.36%',
#   'Volatility M': '0.41%',
#   'Recom': '3.00',
#   'Avg Volume': '1.34M',
#   'Rel Volume': '1.02',
#   'Price': '46.85',
#   'Change': '-0.17%',
#   'Volume': '888,225'},
#  {'No.': '105',
#   'Ticker': 'ECHO',
#   'Perf Week': '-0.52%',
#   'Perf Month': '44.22%',
#   'Perf Quart': '65.86%',
#   'Perf Half': '47.47%',
#   'Perf Year': '81.56%',
#   'Perf YTD': '78.04%',
#   'Volatility W': '0.82%',
#   'Volatility M': '0.91%',
#   'Recom': '2.00',
#   'Avg Volume': '486.74K',
#   'Rel Volume': '1.08',
#   'Price': '47.77',
#   'Change': '0.04%',
#   'Volume': '341,720'},
#  {'No.': '106',
#   'Ticker': 'HGV',
#   'Perf Week': '-4.13%',
#   'Perf Month': '7.24%',
#   'Perf Quart': '17.82%',
#   'Perf Half': '24.89%',
#   'Perf Year': '121.93%',
#   'Perf YTD': '52.70%',
#   'Volatility W': '3.34%',
#   'Volatility M': '2.98%',
#   'Recom': '2.70',
#   'Avg Volume': '721.64K',
#   'Rel Volume': '0.50',
#   'Price': '48.22',
#   'Change': '0.73%',
#   'Volume': '232,863'},
#  {'No.': '107',
#   'Ticker': 'LSXMA',
#   'Perf Week': '0.55%',
#   'Perf Month': '-4.73%',
#   'Perf Quart': '1.99%',
#   'Perf Half': '3.78%',
#   'Perf Year': '40.27%',
#   'Perf YTD': '10.53%',
#   'Volatility W': '1.75%',
#   'Volatility M': '1.82%',
#   'Recom': '1.70',
#   'Avg Volume': '527.65K',
#   'Rel Volume': '0.65',
#   'Price': '48.32',
#   'Change': '1.21%',
#   'Volume': '222,589'},
#  {'No.': '108',
#   'Ticker': 'LSXMK',
#   'Perf Week': '0.99%',
#   'Perf Month': '-3.76%',
#   'Perf Quart': '3.42%',
#   'Perf Half': '4.91%',
#   'Perf Year': '40.54%',
#   'Perf YTD': '10.60%',
#   'Volatility W': '1.79%',
#   'Volatility M': '1.85%',
#   'Recom': '1.50',
#   'Avg Volume': '702.04K',
#   'Rel Volume': '0.61',
#   'Price': '48.75',
#   'Change': '1.31%',
#   'Volume': '277,582'},
#  {'No.': '109',
#   'Ticker': 'LAZ',
#   'Perf Week': '2.21%',
#   'Perf Month': '-1.21%',
#   'Perf Quart': '4.92%',
#   'Perf Half': '7.67%',
#   'Perf Year': '40.27%',
#   'Perf YTD': '13.88%',
#   'Volatility W': '2.90%',
#   'Volatility M': '2.35%',
#   'Recom': '2.20',
#   'Avg Volume': '451.48K',
#   'Rel Volume': '1.05',
#   'Price': '48.83',
#   'Change': '1.37%',
#   'Volume': '306,887'},
#  {'No.': '110',
#   'Ticker': 'AA',
#   'Perf Week': '-4.62%',
#   'Perf Month': '4.84%',
#   'Perf Quart': '34.85%',
#   'Perf Half': '57.07%',
#   'Perf Year': '316.07%',
#   'Perf YTD': '113.36%',
#   'Volatility W': '4.01%',
#   'Volatility M': '4.71%',
#   'Recom': '2.00',
#   'Avg Volume': '7.69M',
#   'Rel Volume': '0.53',
#   'Price': '48.90',
#   'Change': '-0.57%',
#   'Volume': '2,643,427'},
#  {'No.': '111',
#   'Ticker': 'OLN',
#   'Perf Week': '-3.98%',
#   'Perf Month': '-0.96%',
#   'Perf Quart': '11.28%',
#   'Perf Half': '23.00%',
#   'Perf Year': '276.80%',
#   'Perf YTD': '98.37%',
#   'Volatility W': '3.53%',
#   'Volatility M': '3.50%',
#   'Recom': '1.80',
#   'Avg Volume': '1.28M',
#   'Rel Volume': '0.70',
#   'Price': '49.47',
#   'Change': '1.54%',
#   'Volume': '582,879'},
#  {'No.': '112',
#   'Ticker': 'PNM',
#   'Perf Week': '0.20%',
#   'Perf Month': '0.02%',
#   'Perf Quart': '1.33%',
#   'Perf Half': '0.65%',
#   'Perf Year': '15.73%',
#   'Perf YTD': '2.20%',
#   'Volatility W': '0.44%',
#   'Volatility M': '0.43%',
#   'Recom': '3.20',
#   'Avg Volume': '622.90K',
#   'Rel Volume': '0.61',
#   'Price': '49.58',
#   'Change': '-0.03%',
#   'Volume': '246,799'},
#  {'No.': '113',
#   'Ticker': 'GDEN',
#   'Perf Week': '-2.45%',
#   'Perf Month': '5.32%',
#   'Perf Quart': '11.16%',
#   'Perf Half': '73.11%',
#   'Perf Year': '245.24%',
#   'Perf YTD': '145.95%',
#   'Volatility W': '4.40%',
#   'Volatility M': '4.96%',
#   'Recom': '1.70',
#   'Avg Volume': '223.08K',
#   'Rel Volume': '0.43',
#   'Price': '49.91',
#   'Change': '2.02%',
#   'Volume': '62,302'},
#  {'No.': '114',
#   'Ticker': 'AB',
#   'Perf Week': '-2.59%',
#   'Perf Month': '-2.84%',
#   'Perf Quart': '6.43%',
#   'Perf Half': '23.51%',
#   'Perf Year': '86.68%',
#   'Perf YTD': '49.04%',
#   'Volatility W': '2.68%',
#   'Volatility M': '2.54%',
#   'Recom': '2.40',
#   'Avg Volume': '256.91K',
#   'Rel Volume': '0.62',
#   'Price': '50.61',
#   'Change': '0.56%',
#   'Volume': '103,438'},
#  {'No.': '115',
#   'Ticker': 'ACC',
#   'Perf Week': '2.60%',
#   'Perf Month': '-1.94%',
#   'Perf Quart': '4.90%',
#   'Perf Half': '15.46%',
#   'Perf Year': '34.85%',
#   'Perf YTD': '19.06%',
#   'Volatility W': '2.43%',
#   'Volatility M': '2.00%',
#   'Recom': '2.10',
#   'Avg Volume': '715.69K',
#   'Rel Volume': '1.51',
#   'Price': '50.90',
#   'Change': '-0.04%',
#   'Volume': '702,852'},
#  {'No.': '116',
#   'Ticker': 'EPR',
#   'Perf Week': '1.01%',
#   'Perf Month': '1.51%',
#   'Perf Quart': '-1.03%',
#   'Perf Half': '7.73%',
#   'Perf Year': '81.00%',
#   'Perf YTD': '59.45%',
#   'Volatility W': '2.58%',
#   'Volatility M': '2.73%',
#   'Recom': '2.70',
#   'Avg Volume': '545.98K',
#   'Rel Volume': '0.68',
#   'Price': '51.63',
#   'Change': '-0.37%',
#   'Volume': '240,079'},
#  {'No.': '117',
#   'Ticker': 'TRGP',
#   'Perf Week': '5.28%',
#   'Perf Month': '15.58%',
#   'Perf Quart': '18.39%',
#   'Perf Half': '67.11%',
#   'Perf Year': '263.87%',
#   'Perf YTD': '97.38%',
#   'Volatility W': '2.98%',
#   'Volatility M': '2.75%',
#   'Recom': '1.90',
#   'Avg Volume': '1.41M',
#   'Rel Volume': '0.65',
#   'Price': '51.88',
#   'Change': '-0.36%',
#   'Volume': '596,647'},
#  {'No.': '118',
#   'Ticker': 'LEGN',
#   'Perf Week': '8.45%',
#   'Perf Month': '24.75%',
#   'Perf Quart': '29.47%',
#   'Perf Half': '69.19%',
#   'Perf Year': '68.02%',
#   'Perf YTD': '80.97%',
#   'Volatility W': '5.50%',
#   'Volatility M': '5.11%',
#   'Recom': '1.50',
#   'Avg Volume': '383.26K',
#   'Rel Volume': '0.71',
#   'Price': '52.30',
#   'Change': '2.63%',
#   'Volume': '176,759'},
#  {'No.': '119',
#   'Ticker': 'EGLE',
#   'Perf Week': '-0.54%',
#   'Perf Month': '-0.58%',
#   'Perf Quart': '13.07%',
#   'Perf Half': '44.74%',
#   'Perf Year': '179.04%',
#   'Perf YTD': '162.74%',
#   'Volatility W': '6.08%',
#   'Volatility M': '5.38%',
#   'Recom': '1.70',
#   'Avg Volume': '215.93K',
#   'Rel Volume': '1.52',
#   'Price': '52.63',
#   'Change': '5.43%',
#   'Volume': '213,498'},
#  {'No.': '120',
#   'Ticker': 'MDP',
#   'Perf Week': '-1.61%',
#   'Perf Month': '26.92%',
#   'Perf Quart': '32.72%',
#   'Perf Half': '79.23%',
#   'Perf Year': '317.34%',
#   'Perf YTD': '185.83%',
#   'Volatility W': '2.38%',
#   'Volatility M': '3.25%',
#   'Recom': '2.70',
#   'Avg Volume': '313.52K',
#   'Rel Volume': '1.22',
#   'Price': '54.15',
#   'Change': '-1.33%',
#   'Volume': '249,052'},
#  {'No.': '121',
#   'Ticker': 'RRR',
#   'Perf Week': '4.02%',
#   'Perf Month': '14.30%',
#   'Perf Quart': '30.88%',
#   'Perf Half': '58.48%',
#   'Perf Year': '202.18%',
#   'Perf YTD': '116.13%',
#   'Volatility W': '3.99%',
#   'Volatility M': '4.07%',
#   'Recom': '2.40',
#   'Avg Volume': '712.47K',
#   'Rel Volume': '0.87',
#   'Price': '54.50',
#   'Change': '0.70%',
#   'Volume': '404,700'},
#  {'No.': '122',
#   'Ticker': 'FOCS',
#   'Perf Week': '-0.36%',
#   'Perf Month': '-0.86%',
#   'Perf Quart': '3.59%',
#   'Perf Half': '25.39%',
#   'Perf Year': '61.12%',
#   'Perf YTD': '22.05%',
#   'Volatility W': '2.27%',
#   'Volatility M': '2.97%',
#   'Recom': '1.70',
#   'Avg Volume': '368.02K',
#   'Rel Volume': '1.19',
#   'Price': '55.22',
#   'Change': '4.00%',
#   'Volume': '284,563'},
#  {'No.': '123',
#   'Ticker': 'SAH',
#   'Perf Week': '-1.29%',
#   'Perf Month': '12.21%',
#   'Perf Quart': '26.73%',
#   'Perf Half': '11.80%',
#   'Perf Year': '28.63%',
#   'Perf YTD': '44.91%',
#   'Volatility W': '5.80%',
#   'Volatility M': '4.02%',
#   'Recom': '2.10',
#   'Avg Volume': '324.78K',
#   'Rel Volume': '0.95',
#   'Price': '55.55',
#   'Change': '-0.61%',
#   'Volume': '199,313'},
#  {'No.': '124',
#   'Ticker': 'NFG',
#   'Perf Week': '2.71%',
#   'Perf Month': '6.28%',
#   'Perf Quart': '7.36%',
#   'Perf Half': '11.06%',
#   'Perf Year': '39.31%',
#   'Perf YTD': '35.45%',
#   'Volatility W': '2.76%',
#   'Volatility M': '2.36%',
#   'Recom': '2.30',
#   'Avg Volume': '359.17K',
#   'Rel Volume': '0.70',
#   'Price': '55.64',
#   'Change': '-0.12%',
#   'Volume': '163,161'},
#  {'No.': '125',
#   'Ticker': 'VSAT',
#   'Perf Week': '3.26%',
#   'Perf Month': '8.25%',
#   'Perf Quart': '17.60%',
#   'Perf Half': '11.89%',
#   'Perf Year': '63.72%',
#   'Perf YTD': '72.89%',
#   'Volatility W': '2.87%',
#   'Volatility M': '3.22%',
#   'Recom': '2.00',
#   'Avg Volume': '394.44K',
#   'Rel Volume': '0.32',
#   'Price': '55.76',
#   'Change': '-1.22%',
#   'Volume': '81,263'},
#  {'No.': '126',
#   'Ticker': 'CLDX',
#   'Perf Week': '2.29%',
#   'Perf Month': '3.42%',
#   'Perf Quart': '79.78%',
#   'Perf Half': '168.59%',
#   'Perf Year': '275.38%',
#   'Perf YTD': '221.18%',
#   'Volatility W': '4.68%',
#   'Volatility M': '4.15%',
#   'Recom': '1.70',
#   'Avg Volume': '825.42K',
#   'Rel Volume': '0.29',
#   'Price': '55.99',
#   'Change': '-0.50%',
#   'Volume': '155,252'},
#  {'No.': '127',
#   'Ticker': 'EGRX',
#   'Perf Week': '2.37%',
#   'Perf Month': '6.64%',
#   'Perf Quart': '24.37%',
#   'Perf Half': '40.00%',
#   'Perf Year': '34.66%',
#   'Perf YTD': '20.64%',
#   'Volatility W': '4.17%',
#   'Volatility M': '3.76%',
#   'Recom': '2.30',
#   'Avg Volume': '106.63K',
#   'Rel Volume': '0.83',
#   'Price': '56.06',
#   'Change': '-0.21%',
#   'Volume': '57,346'},
#  {'No.': '128',
#   'Ticker': 'L',
#   'Perf Week': '2.06%',
#   'Perf Month': '-0.79%',
#   'Perf Quart': '2.08%',
#   'Perf Half': '3.71%',
#   'Perf Year': '55.01%',
#   'Perf YTD': '22.23%',
#   'Volatility W': '2.33%',
#   'Volatility M': '1.89%',
#   'Recom': '3.00',
#   'Avg Volume': '909.04K',
#   'Rel Volume': '0.45',
#   'Price': '56.27',
#   'Change': '2.25%',
#   'Volume': '267,581'},
#  {'No.': '129',
#   'Ticker': 'BIP',
#   'Perf Week': '0.62%',
#   'Perf Month': '-0.68%',
#   'Perf Quart': '1.62%',
#   'Perf Half': '3.59%',
#   'Perf Year': '18.39%',
#   'Perf YTD': '14.55%',
#   'Volatility W': '1.70%',
#   'Volatility M': '1.63%',
# ...
#   'Perf Year': '62.88%',
#   'Perf YTD': '17.60%',
#   'Volatility W': '3.01%',
#   'Volatility M': '2.68%',
#   'Recom': '2.50',
#   'Avg Volume': '2.07M',
#   'Rel Volume': '0.67',
#   'Price': '155.69',
#   'Change': '0.35%',
#   'Volume': '892,864'},
#  {'No.': '228',
#   'Ticker': 'DRI',
#   'Perf Week': '-2.68%',
#   'Perf Month': '3.29%',
#   'Perf Quart': '4.46%',
#   'Perf Half': '7.66%',
#   'Perf Year': '49.24%',
#   'Perf YTD': '30.56%',
#   'Volatility W': '2.66%',
#   'Volatility M': '2.32%',
#   'Recom': '2.10',
#   'Avg Volume': '1.55M',
#   'Rel Volume': '0.43',
#   'Price': '157.09',
#   'Change': '1.01%',
#   'Volume': '431,149'},
#  {'No.': '229',
#   'Ticker': 'APTV',
#   'Perf Week': '2.24%',
#   'Perf Month': '4.36%',
#   'Perf Quart': '0.04%',
#   'Perf Half': '9.27%',
#   'Perf Year': '68.51%',
#   'Perf YTD': '21.01%',
#   'Volatility W': '3.04%',
#   'Volatility M': '2.69%',
#   'Recom': '2.20',
#   'Avg Volume': '1.28M',
#   'Rel Volume': '1.01',
#   'Price': '158.92',
#   'Change': '0.80%',
#   'Volume': '841,288'},
#  {'No.': '230',
#   'Ticker': 'CE',
#   'Perf Week': '-1.28%',
#   'Perf Month': '-1.99%',
#   'Perf Quart': '2.06%',
#   'Perf Half': '-0.16%',
#   'Perf Year': '41.60%',
#   'Perf YTD': '17.96%',
#   'Volatility W': '2.34%',
#   'Volatility M': '2.28%',
#   'Recom': '2.10',
#   'Avg Volume': '679.75K',
#   'Rel Volume': '0.75',
#   'Price': '159.17',
#   'Change': '3.84%',
#   'Volume': '329,736'},
#  {'No.': '231',
#   'Ticker': 'LPLA',
#   'Perf Week': '-2.13%',
#   'Perf Month': '5.11%',
#   'Perf Quart': '15.07%',
#   'Perf Half': '9.84%',
#   'Perf Year': '104.47%',
#   'Perf YTD': '51.30%',
#   'Volatility W': '2.96%',
#   'Volatility M': '2.84%',
#   'Recom': '1.70',
#   'Avg Volume': '451.62K',
#   'Rel Volume': '1.10',
#   'Price': '161.01',
#   'Change': '2.11%',
#   'Volume': '322,891'},
#  {'No.': '232',
#   'Ticker': 'MUSA',
#   'Perf Week': '0.00%',
#   'Perf Month': '8.36%',
#   'Perf Quart': '28.00%',
#   'Perf Half': '17.51%',
#   'Perf Year': '32.56%',
#   'Perf YTD': '29.30%',
#   'Volatility W': '2.78%',
#   'Volatility M': '3.05%',
#   'Recom': '2.60',
#   'Avg Volume': '201.26K',
#   'Rel Volume': '0.61',
#   'Price': '164.79',
#   'Change': '-2.62%',
#   'Volume': '79,708'},
#  {'No.': '233',
#   'Ticker': 'HRI',
#   'Perf Week': '5.25%',
#   'Perf Month': '31.00%',
#   'Perf Quart': '55.74%',
#   'Perf Half': '72.45%',
#   'Perf Year': '307.94%',
#   'Perf YTD': '158.49%',
#   'Volatility W': '4.46%',
#   'Volatility M': '4.25%',
#   'Recom': '1.90',
#   'Avg Volume': '209.96K',
#   'Rel Volume': '1.43',
#   'Price': '171.00',
#   'Change': '-0.38%',
#   'Volume': '195,170'},
#  {'No.': '234',
#   'Ticker': 'WTS',
#   'Perf Week': '-2.75%',
#   'Perf Month': '-0.07%',
#   'Perf Quart': '16.70%',
#   'Perf Half': '40.93%',
#   'Perf Year': '65.72%',
#   'Perf YTD': '38.59%',
#   'Volatility W': '2.82%',
#   'Volatility M': '2.31%',
#   'Recom': '3.00',
#   'Avg Volume': '120.38K',
#   'Rel Volume': '0.67',
#   'Price': '173.19',
#   'Change': '2.68%',
#   'Volume': '52,073'},
#  {'No.': '235',
#   'Ticker': 'AXP',
#   'Perf Week': '-2.33%',
#   'Perf Month': '6.55%',
#   'Perf Quart': '1.83%',
#   'Perf Half': '18.14%',
#   'Perf Year': '69.92%',
#   'Perf YTD': '42.80%',
#   'Volatility W': '2.83%',
#   'Volatility M': '2.24%',
#   'Recom': '2.50',
#   'Avg Volume': '3.80M',
#   'Rel Volume': '0.50',
#   'Price': '175.68',
#   'Change': '1.75%',
#   'Volume': '1,231,087'},
#  {'No.': '236',
#   'Ticker': 'SYNA',
#   'Perf Week': '-5.36%',
#   'Perf Month': '-7.98%',
#   'Perf Quart': '11.55%',
#   'Perf Half': '26.05%',
#   'Perf Year': '124.39%',
#   'Perf YTD': '81.98%',
#   'Volatility W': '3.29%',
#   'Volatility M': '2.60%',
#   'Recom': '2.20',
#   'Avg Volume': '363.86K',
#   'Rel Volume': '0.61',
#   'Price': '177.94',
#   'Change': '1.43%',
#   'Volume': '143,543'},
#  {'No.': '237',
#   'Ticker': 'CNXC',
#   'Perf Week': '4.51%',
#   'Perf Month': '-1.34%',
#   'Perf Quart': '8.42%',
#   'Perf Half': '15.73%',
#   'Perf Year': '-',
#   'Perf YTD': '77.24%',
#   'Volatility W': '4.86%',
#   'Volatility M': '3.42%',
#   'Recom': '1.00',
#   'Avg Volume': '160.17K',
#   'Rel Volume': '0.90',
#   'Price': '179.50',
#   'Change': '2.61%',
#   'Volume': '94,039'},
#  {'No.': '238',
#   'Ticker': 'PXD',
#   'Perf Week': '6.52%',
#   'Perf Month': '19.43%',
#   'Perf Quart': '11.19%',
#   'Perf Half': '18.23%',
#   'Perf Year': '106.81%',
#   'Perf YTD': '57.14%',
#   'Volatility W': '3.14%',
#   'Volatility M': '3.15%',
#   'Recom': '1.90',
#   'Avg Volume': '2.00M',
#   'Rel Volume': '1.42',
#   'Price': '181.48',
#   'Change': '1.40%',
#   'Volume': '1,847,974'},
#  {'No.': '239',
#   'Ticker': 'GPI',
#   'Perf Week': '-5.05%',
#   'Perf Month': '19.00%',
#   'Perf Quart': '28.25%',
#   'Perf Half': '22.92%',
#   'Perf Year': '97.24%',
#   'Perf YTD': '46.39%',
#   'Volatility W': '4.46%',
#   'Volatility M': '3.73%',
#   'Recom': '1.90',
#   'Avg Volume': '179.68K',
#   'Rel Volume': '0.82',
#   'Price': '188.69',
#   'Change': '-1.71%',
#   'Volume': '96,138'},
#  {'No.': '240',
#   'Ticker': 'TXN',
#   'Perf Week': '-4.96%',
#   'Perf Month': '0.52%',
#   'Perf Quart': '-0.42%',
#   'Perf Half': '-2.15%',
#   'Perf Year': '34.95%',
#   'Perf YTD': '16.01%',
#   'Volatility W': '2.16%',
#   'Volatility M': '1.67%',
#   'Recom': '2.50',
#   'Avg Volume': '3.54M',
#   'Rel Volume': '0.70',
#   'Price': '194.78',
#   'Change': '2.30%',
#   'Volume': '1,607,200'},
#  {'No.': '241',
#   'Ticker': 'ALNY',
#   'Perf Week': '0.60%',
#   'Perf Month': '-2.58%',
#   'Perf Quart': '11.84%',
#   'Perf Half': '37.33%',
#   'Perf Year': '43.74%',
#   'Perf YTD': '50.05%',
#   'Volatility W': '4.61%',
#   'Volatility M': '3.45%',
#   'Recom': '2.40',
#   'Avg Volume': '612.51K',
#   'Rel Volume': '0.38',
#   'Price': '196.72',
#   'Change': '0.87%',
#   'Volume': '153,065'},
#  {'No.': '242',
#   'Ticker': 'TSCO',
#   'Perf Week': '-6.80%',
#   'Perf Month': '0.20%',
#   'Perf Quart': '5.15%',
#   'Perf Half': '9.19%',
#   'Perf Year': '39.38%',
#   'Perf YTD': '39.42%',
#   'Volatility W': '2.33%',
#   'Volatility M': '2.06%',
#   'Recom': '2.30',
#   'Avg Volume': '856.41K',
#   'Rel Volume': '0.57',
#   'Price': '198.08',
#   'Change': '1.06%',
#   'Volume': '316,952'},
#  {'No.': '243',
#   'Ticker': 'FRC',
#   'Perf Week': '-1.16%',
#   'Perf Month': '-2.11%',
#   'Perf Quart': '4.34%',
#   'Perf Half': '16.83%',
#   'Perf Year': '74.86%',
#   'Perf YTD': '34.41%',
#   'Volatility W': '2.74%',
#   'Volatility M': '1.93%',
#   'Recom': '2.60',
#   'Avg Volume': '657.60K',
#   'Rel Volume': '0.54',
#   'Price': '201.76',
#   'Change': '2.16%',
#   'Volume': '230,606'},
#  {'No.': '244',
#   'Ticker': 'VRSK',
#   'Perf Week': '-2.41%',
#   'Perf Month': '-2.83%',
#   'Perf Quart': '11.94%',
#   'Perf Half': '9.91%',
#   'Perf Year': '9.18%',
#   'Perf YTD': '-4.23%',
#   'Volatility W': '1.69%',
#   'Volatility M': '1.57%',
#   'Recom': '2.20',
#   'Avg Volume': '836.81K',
#   'Rel Volume': '0.32',
#   'Price': '201.96',
#   'Change': '1.58%',
#   'Volume': '175,661'},
#  {'No.': '245',
#   'Ticker': 'NDSN',
#   'Perf Week': '-1.72%',
#   'Perf Month': '-0.82%',
#   'Perf Quart': '10.30%',
#   'Perf Half': '18.52%',
#   'Perf Year': '26.31%',
#   'Perf YTD': '19.73%',
#   'Volatility W': '2.06%',
#   'Volatility M': '1.61%',
#   'Recom': '2.20',
#   'Avg Volume': '170.31K',
#   'Rel Volume': '0.59',
#   'Price': '241.67',
#   'Change': '0.45%',
#   'Volume': '65,248'},
#  {'No.': '246',
#   'Ticker': 'CHDN',
#   'Perf Week': '1.48%',
#   'Perf Month': '14.67%',
#   'Perf Quart': '27.07%',
#   'Perf Half': '6.98%',
#   'Perf Year': '44.15%',
#   'Perf YTD': '26.70%',
#   'Volatility W': '2.50%',
#   'Volatility M': '2.56%',
#   'Recom': '1.60',
#   'Avg Volume': '243.48K',
#   'Rel Volume': '0.60',
#   'Price': '244.52',
#   'Change': '-0.92%',
#   'Volume': '95,483'},
#  {'No.': '247',
#   'Ticker': 'MCD',
#   'Perf Week': '-2.03%',
#   'Perf Month': '1.34%',
#   'Perf Quart': '4.44%',
#   'Perf Half': '4.82%',
#   'Perf Year': '9.17%',
#   'Perf YTD': '13.28%',
#   'Volatility W': '1.60%',
#   'Volatility M': '1.36%',
#   'Recom': '2.00',
#   'Avg Volume': '2.42M',
#   'Rel Volume': '0.66',
#   'Price': '246.35',
#   'Change': '1.35%',
#   'Volume': '1,039,449'},
#  {'No.': '248',
#   'Ticker': 'JLL',
#   'Perf Week': '1.67%',
#   'Perf Month': '3.94%',
#   'Perf Quart': '32.64%',
#   'Perf Half': '38.58%',
#   'Perf Year': '154.87%',
#   'Perf YTD': '70.41%',
#   'Volatility W': '3.01%',
#   'Volatility M': '2.45%',
#   'Recom': '2.00',
#   'Avg Volume': '334.05K',
#   'Rel Volume': '0.63',
#   'Price': '254.86',
#   'Change': '0.80%',
#   'Volume': '135,649'},
#  {'No.': '249',
#   'Ticker': 'MOH',
#   'Perf Week': '-4.67%',
#   'Perf Month': '-1.16%',
#   'Perf Quart': '5.41%',
#   'Perf Half': '15.50%',
#   'Perf Year': '39.38%',
#   'Perf YTD': '26.72%',
#   'Volatility W': '3.18%',
#   'Volatility M': '3.10%',
#   'Recom': '2.40',
#   'Avg Volume': '275.09K',
#   'Rel Volume': '0.73',
#   'Price': '268.26',
#   'Change': '-0.46%',
#   'Volume': '129,984'},
#  {'No.': '250',
#   'Ticker': 'CRM',
#   'Perf Week': '-3.15%',
#   'Perf Month': '2.54%',
#   'Perf Quart': '8.24%',
#   'Perf Half': '22.51%',
#   'Perf Year': '9.28%',
#   'Perf YTD': '21.72%',
#   'Volatility W': '2.43%',
#   'Volatility M': '2.04%',
#   'Recom': '1.90',
#   'Avg Volume': '6.20M',
#   'Rel Volume': '0.44',
#   'Price': '272.22',
#   'Change': '0.50%',
#   'Volume': '1,765,046'},
#  {'No.': '251',
#   'Ticker': 'AMP',
#   'Perf Week': '-4.58%',
#   'Perf Month': '-3.30%',
#   'Perf Quart': '7.16%',
#   'Perf Half': '12.04%',
#   'Perf Year': '66.75%',
#   'Perf YTD': '36.31%',
#   'Volatility W': '2.78%',
#   'Volatility M': '2.31%',
#   'Recom': '1.90',
#   'Avg Volume': '454.74K',
#   'Rel Volume': '0.64',
#   'Price': '272.90',
#   'Change': '3.02%',
#   'Volume': '187,752'},
#  {'No.': '252',
#   'Ticker': 'PCTY',
#   'Perf Week': '-6.39%',
#   'Perf Month': '0.56%',
#   'Perf Quart': '39.94%',
#   'Perf Half': '46.16%',
#   'Perf Year': '66.51%',
#   'Perf YTD': '33.08%',
#   'Volatility W': '3.56%',
#   'Volatility M': '3.02%',
#   'Recom': '2.10',
#   'Avg Volume': '228.00K',
#   'Rel Volume': '0.68',
#   'Price': '278.40',
#   'Change': '1.60%',
#   'Volume': '100,492'},
#  {'No.': '253',
#   'Ticker': 'SBNY',
#   'Perf Week': '4.69%',
#   'Perf Month': '10.32%',
#   'Perf Quart': '20.09%',
#   'Perf Half': '29.52%',
#   'Perf Year': '248.86%',
#   'Perf YTD': '114.07%',
#   'Volatility W': '3.42%',
#   'Volatility M': '3.04%',
#   'Recom': '1.70',
#   'Avg Volume': '507.98K',
#   'Rel Volume': '0.68',
#   'Price': '289.38',
#   'Change': '-0.08%',
#   'Volume': '225,101'},
#  {'No.': '254',
#   'Ticker': 'ODFL',
#   'Perf Week': '-5.08%',
#   'Perf Month': '-5.51%',
#   'Perf Quart': '11.33%',
#   'Perf Half': '15.85%',
#   'Perf Year': '53.53%',
#   'Perf YTD': '45.18%',
#   'Volatility W': '2.53%',
#   'Volatility M': '2.11%',
#   'Recom': '2.50',
#   'Avg Volume': '542.70K',
#   'Rel Volume': '0.33',
#   'Price': '289.98',
#   'Change': '2.34%',
#   'Volume': '118,016'},
#  {'No.': '255',
#   'Ticker': 'IT',
#   'Perf Week': '-3.17%',
#   'Perf Month': '-2.14%',
#   'Perf Quart': '19.95%',
#   'Perf Half': '61.21%',
#   'Perf Year': '143.44%',
#   'Perf YTD': '90.48%',
#   'Volatility W': '2.61%',
#   'Volatility M': '2.42%',
#   'Recom': '2.10',
#   'Avg Volume': '576.08K',
#   'Rel Volume': '0.57',
#   'Price': '311.55',
#   'Change': '2.10%',
#   'Volume': '214,280'},
#  {'No.': '256',
#   'Ticker': 'MTN',
#   'Perf Week': '-0.15%',
#   'Perf Month': '16.13%',
#   'Perf Quart': '7.20%',
#   'Perf Half': '12.80%',
#   'Perf Year': '58.11%',
#   'Perf YTD': '23.13%',
#   'Volatility W': '3.06%',
#   'Volatility M': '3.36%',
#   'Recom': '2.60',
#   'Avg Volume': '298.60K',
#   'Rel Volume': '0.70',
#   'Price': '340.55',
#   'Change': '-0.85%',
#   'Volume': '136,568'},
#  {'No.': '257',
#   'Ticker': 'URI',
#   'Perf Week': '-4.67%',
#   'Perf Month': '-1.41%',
#   'Perf Quart': '11.99%',
#   'Perf Half': '7.17%',
#   'Perf Year': '88.50%',
#   'Perf YTD': '50.39%',
#   'Volatility W': '3.02%',
#   'Volatility M': '3.04%',
#   'Recom': '2.30',
#   'Avg Volume': '642.64K',
#   'Rel Volume': '1.06',
#   'Price': '353.52',
#   'Change': '1.37%',
#   'Volume': '441,661'},
#  {'No.': '258',
#   'Ticker': 'ULTA',
#   'Perf Week': '-2.94%',
#   'Perf Month': '-2.96%',
#   'Perf Quart': '5.10%',
#   'Perf Half': '17.26%',
#   'Perf Year': '61.76%',
#   'Perf YTD': '28.82%',
#   'Volatility W': '2.54%',
#   'Volatility M': '2.35%',
#   'Recom': '2.30',
#   'Avg Volume': '610.42K',
#   'Rel Volume': '0.77',
#   'Price': '377.10',
#   'Change': '1.94%',
#   'Volume': '303,461'},
#  {'No.': '259',
#   'Ticker': 'TEAM',
#   'Perf Week': '-2.34%',
#   'Perf Month': '1.78%',
#   'Perf Quart': '42.57%',
#   'Perf Half': '71.52%',
#   'Perf Year': '107.11%',
#   'Perf YTD': '63.64%',
#   'Volatility W': '3.37%',
#   'Volatility M': '2.91%',
#   'Recom': '2.00',
#   'Avg Volume': '1.07M',
#   'Rel Volume': '0.76',
#   'Price': '391.02',
#   'Change': '2.17%',
#   'Volume': '526,822'},
#  {'No.': '260',
#   'Ticker': 'PANW',
#   'Perf Week': '-3.39%',
#   'Perf Month': '1.51%',
#   'Perf Quart': '19.81%',
#   'Perf Half': '39.17%',
#   'Perf Year': '91.52%',
#   'Perf YTD': '32.12%',
#   'Volatility W': '2.73%',
#   'Volatility M': '2.37%',
#   'Recom': '1.80',
#   'Avg Volume': '1.33M',
#   'Rel Volume': '0.55',
#   'Price': '476.98',
#   'Change': '1.58%',
#   'Volume': '477,853'},
#  {'No.': '261',
#   'Ticker': 'DXCM',
#   'Perf Week': '-4.12%',
#   'Perf Month': '-2.46%',
#   'Perf Quart': '19.47%',
#   'Perf Half': '41.13%',
#   'Perf Year': '36.91%',
#   'Perf YTD': '42.39%',
#   'Volatility W': '3.18%',
#   'Volatility M': '2.76%',
#   'Recom': '1.60',
#   'Avg Volume': '588.17K',
#   'Rel Volume': '0.72',
#   'Price': '540.99',
#   'Change': '2.77%',
#   'Volume': '275,853'},
#  {'No.': '262',
#   'Ticker': 'TMO',
#   'Perf Week': '-4.32%',
#   'Perf Month': '0.62%',
#   'Perf Quart': '10.05%',
#   'Perf Half': '21.39%',
#   'Perf Year': '30.79%',
#   'Perf YTD': '22.16%',
#   'Volatility W': '2.84%',
#   'Volatility M': '2.44%',
#   'Recom': '1.80',
#   'Avg Volume': '1.20M',
#   'Rel Volume': '0.90',
#   'Price': '575.08',
#   'Change': '1.07%',
#   'Volume': '696,283'},
#  {'No.': '263',
#   'Ticker': 'ORLY',
#   'Perf Week': '-4.07%',
#   'Perf Month': '3.36%',
#   'Perf Quart': '3.12%',
#   'Perf Half': '16.34%',
#   'Perf Year': '30.56%',
#   'Perf YTD': '32.20%',
#   'Volatility W': '2.52%',
#   'Volatility M': '1.79%',
#   'Recom': '2.20',
#   'Avg Volume': '400.51K',
#   'Rel Volume': '0.82',
#   'Price': '607.85',
#   'Change': '1.60%',
#   'Volume': '213,104'},
#  {'No.': '264',
#   'Ticker': 'CACC',
#   'Perf Week': '0.34%',
#   'Perf Month': '-8.52%',
#   'Perf Quart': '33.94%',
#   'Perf Half': '68.11%',
#   'Perf Year': '70.59%',
#   'Perf YTD': '74.43%',
#   'Volatility W': '2.80%',
#   'Volatility M': '3.18%',
#   'Recom': '3.30',
#   'Avg Volume': '150.94K',
#   'Rel Volume': '1.09',
#   'Price': '611.25',
#   'Change': '1.24%',
#   'Volume': '106,329'},
#  {'No.': '265',
#   'Ticker': 'NOW',
#   'Perf Week': '-4.86%',
#   'Perf Month': '-6.41%',
#   'Perf Quart': '10.65%',
#   'Perf Half': '21.39%',
#   'Perf Year': '25.31%',
#   'Perf YTD': '12.27%',
#   'Volatility W': '3.34%',
#   'Volatility M': '2.27%',
#   'Recom': '1.70',
#   'Avg Volume': '1.00M',
#   'Rel Volume': '0.88',
#   'Price': '636.24',
#   'Change': '2.96%',
#   'Volume': '571,239'},
#  {'No.': '266',
#   'Ticker': 'TDG',
#   'Perf Week': '-0.74%',
#   'Perf Month': '5.61%',
#   'Perf Quart': '-1.89%',
#   'Perf Half': '4.82%',
#   'Perf Year': '32.63%',
#   'Perf YTD': '4.07%',
#   'Volatility W': '2.83%',
#   'Volatility M': '2.37%',
#   'Recom': '2.20',
#   'Avg Volume': '230.90K',
#   'Rel Volume': '0.37',
#   'Price': '647.20',
#   'Change': '0.50%',
#   'Volume': '55,301'},
#  {'No.': '267',
#   'Ticker': 'SIVB',
#   'Perf Week': '-3.72%',
#   'Perf Month': '13.99%',
#   'Perf Quart': '18.06%',
#   'Perf Half': '32.57%',
#   'Perf Year': '164.34%',
#   'Perf YTD': '67.43%',
#   'Volatility W': '3.27%',
#   'Volatility M': '3.07%',
#   'Recom': '2.30',
#   'Avg Volume': '397.20K',
#   'Rel Volume': '0.68',
#   'Price': '663.66',
#   'Change': '2.20%',
#   'Volume': '176,528'},
#  {'No.': '268',
#   'Ticker': 'AZO',
#   'Perf Week': '-2.89%',
#   'Perf Month': '8.01%',
#   'Perf Quart': '6.50%',
#   'Perf Half': '14.71%',
#   'Perf Year': '39.55%',
#   'Perf YTD': '38.56%',
#   'Volatility W': '2.75%',
#   'Volatility M': '2.16%',
#   'Recom': '2.20',
#   'Avg Volume': '162.12K',
#   'Rel Volume': '0.70',
#   'Price': '1659.28',
#   'Change': '1.02%',
#   'Volume': '73,962'},
#  {'No.': '269',
#   'Ticker': 'BKNG',
#   'Perf Week': '-0.69%',
#   'Perf Month': '6.91%',
#   'Perf Quart': '10.67%',
#   'Perf Half': '1.55%',
#   'Perf Year': '43.77%',
#   'Perf YTD': '10.43%',
#   'Volatility W': '2.57%',
#   'Volatility M': '2.35%',
#   'Recom': '2.60',
#   'Avg Volume': '298.34K',
#   'Rel Volume': '0.53',
#   'Price': '2445.56',
#   'Change': '-0.57%',
#   'Volume': '102,810'}]

# %% [markdown]
# # retrieve Ticker data

# %%
#test Ticker
#ticker = yf.Ticker('AMCR')
#ticker_history = ticker.history(period = 'max')
#ticker_history
# Out:
#                  Open       High        Low      Close   Volume  Dividends  \
# Date
# 2012-05-15   5.639252   5.639252   5.639252   5.639252        0        0.0
# 2012-06-07   5.419541   5.419541   5.419541   5.419541     1900        0.0
# 2012-06-08   5.419541   5.419541   5.419541   5.419541        0        0.0
# 2012-08-17   5.712488   5.712488   5.712488   5.712488     1000        0.0
# 2012-08-20   5.712488   5.712488   5.712488   5.712488        0        0.0
# ...               ...        ...        ...        ...      ...        ...
# 2021-09-28  11.890000  11.910000  11.650000  11.700000  5528800        0.0
# 2021-09-29  11.720000  11.810000  11.710000  11.730000  2644200        0.0
# 2021-09-30  11.790000  11.810000  11.570000  11.590000  5867500        0.0
# 2021-10-01  11.710000  11.790000  11.490000  11.690000  5347100        0.0
# 2021-10-04  11.640000  11.770000  11.565000  11.610000  1600370        0.0
#
#             Stock Splits
# Date
# 2012-05-15             0
# 2012-06-07             0
# 2012-06-08             0
# 2012-08-17             0
# 2012-08-20             0
# ...                  ...
# 2021-09-28             0
# 2021-09-29             0
# 2021-09-30             0
# 2021-10-01             0
# 2021-10-04             0
#
# [1178 rows x 7 columns]

# %%
ticker_table =pd.DataFrame(stock_list.data)
ticker_table
ticker_list = ticker_table['Ticker'].to_list()
ticker_list
for ticker_string in tqdm(ticker_list):
    ticker = yf.Ticker(ticker_string)
    ticker_history = ticker.history(period = 'max')
ticker_history
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 268/268 [02:07<00:00,  2.09it/s]
#                    Open         High          Low        Close   Volume  \
# Date
# 1999-03-31   451.500000   517.500000   438.000000   497.250000  1322933
# 1999-04-01   550.500000   552.000000   475.500000   483.000000   483233
# 1999-04-05   501.000000   504.000000   435.000000   450.750000   324917
# 1999-04-06   452.250000   484.125000   420.000000   474.000000   353900
# 1999-04-07   480.750000   487.500000   442.500000   447.000000   156617
# ...                 ...          ...          ...          ...      ...
# 2021-09-29  2436.639893  2447.610107  2374.770020  2377.820068   294300
# 2021-09-30  2382.929932  2406.399902  2355.000000  2373.870117   311600
# 2021-10-01  2416.840088  2476.770020  2416.840088  2455.870117   306600
# 2021-10-04  2455.870117  2488.850098  2421.750000  2459.520020   257400
# 2021-10-05  2459.000000  2486.912109  2436.439941  2444.989990   107043
#
#             Dividends  Stock Splits
# Date
# 1999-03-31          0           0.0
# 1999-04-01          0           0.0
# 1999-04-05          0           0.0
# 1999-04-06          0           0.0
# 1999-04-07          0           0.0
# ...               ...           ...
# 2021-09-29          0           0.0
# 2021-09-30          0           0.0
# 2021-10-01          0           0.0
# 2021-10-04          0           0.0
# 2021-10-05          0           0.0
#
# [5667 rows x 7 columns]

# %% [markdown]
# # define methods

# %%
def slope_reg(arr):
    y = np.array(arr)
    x = np.arange(len(y))
    slope, intercept, r_value, p_value, std_err = linregress(x,y)
    return slope


def stock_filter(df):
    df['SMA_50'] = df['Close'].rolling(window =50).mean()
    df['SMA_150'] = df['Close'].rolling(window =150).mean()
    df['SMA_200'] = df['Close'].rolling(window =200).mean()
    df['SMA_slope_200'] = df['SMA_200'].rolling(window =20).apply(slope_reg)
    df['52_week_low'] = df['Close'].rolling(window =5*52).min()
    df['52_week_high'] = df['Close'].rolling(window =5*52).max()
    
    #Criteria 1 :The current price of the security must be greater than 150 and 200-day simple moving averages.
    df['Criteria1'] =(df['Close'] > df['SMA_150']) & (df['Close'] > df['SMA_200'])
    
    #Criteria 2 : The 150-day simple moving average must be greater than the 200-day simple moving average.
    df['Criteria2'] =(df['SMA_150'] > df['SMA_200'])
    
    #Criteria 3: The 200-day simple moving average must be trending up for at least 1 month.
    df['Criteria3'] = df['SMA_slope_200'] > 0.0
    
    #Criteria 4: The 50-day simple moving average must be greater than the 150 simple moving average and the 200 SMA.
    df['Criteria4'] = ( df['SMA_50'] > df['SMA_150']) & ( df['SMA_150'] > df['SMA_200'])
    
    #Criteria 5: The current price must be greater than the 50-day simple moving average.
    df['Criteria5'] = ( df['Close'] > df['SMA_50'])
    
    #Criteria 6: The current price must be at least 30% above the 52 week low.
    df['Criteria6'] = ( df['Close'] - df['52_week_low'])/df['52_week_low'] > 0.3
    
    #Criteria 7: The current price must be within 15% of the 52 week high.
    df['Criteria7'] = ((df['Close'] - df['52_week_high'])/df['52_week_high'] < 0.15) & ((df['Close'] - df['52_week_high'])/df['52_week_high'] > -0.15)
    
    #Criteria 8: replace RS rating
    df['Criteria8'] = (df['Close'] - df['Close'].shift(periods = 250))/df['Close'].shift(periods = 250) > 0.89
    
    #Criteria 9: Pivot (5day)breakout
    df['Criteria9'] = df['Close'] > ((df['Close']).rolling(window= 5).mean() +( df['Close']).rolling(window=5).max() +(df['Close']).rolling(window= 5).min())/3
    
    #Criteria 10: last contraction below 10% 
    df['Criteria10'] = ((df['Close']).rolling(window =10).max() - (df['Close']).rolling(window =10).min()) / (df['Close'].rolling(window =10).min()) < 0.1
                                                                                                                                                                                                                
    df['Fulfilment'] = df[['Criteria1','Criteria2','Criteria3','Criteria4','Criteria5','Criteria6','Criteria7','Criteria8','Criteria9','Criteria10']].all(axis='columns')
                                                                                                            
    return df[['Close','Fulfilment']]




def show_image(ticker):
    stock = finvizfinance(ticker)
    print(stock.TickerCharts())
    display(Image(url= stock.TickerCharts()))


def test_vcp(df):
    df['Future_Close_1'] = df['Close'].shift(periods = -1)
    df['Future_Close_3'] = df['Close'].shift(periods = -3)
    df['Future_Close_5'] = df['Close'].shift(periods = -5)
    df['Future_Close_7'] = df['Close'].shift(periods = -7)
    df['Future_Close_9'] = df['Close'].shift(periods = -9)
    df['Result_1'] = ( df['Future_Close_3'] - df['Close']) / df['Close']
    df['Result_3'] = ( df['Future_Close_5'] - df['Close']) / df['Close']
    df['Result_5'] = ( df['Future_Close_7'] - df['Close']) / df['Close']
    df['Result_7'] = ( df['Future_Close_9'] - df['Close']) / df['Close']
    vcp_date = df[df['Fulfilment'] == True]
    print(vcp_date[['Result_1','Result_3','Result_5','Result_7']])
    print(vcp_date[['Result_1','Result_3','Result_5','Result_7']].describe())

# %% [markdown]
# # find out and backtest VCP models

# %%
#TEST VCP
# ticker = yf.Ticker("CRVL")
# ticker_history = ticker.history(period = 'max')
# data = stock_filter(ticker_history)
# test_vcp(data)

# %%
tickerList = []          ## 空列表
for ticker_string in tqdm(ticker_list):
    ticker = yf.Ticker(ticker_string)
    ticker_history = ticker.history(period = 'max')
    data = stock_filter(ticker_history)
    if data['Fulfilment'].tail(1).iloc[0] == True:
        print(ticker_string)
        print(data)
        show_image(ticker_string)
        tickerList.append(ticker_string)
        #test_vcp(data)
# Out:
#   1%|▉                                                                                 | 3/268 [00:03<04:44,  1.07s/it]
# TILE
#                 Close  Fulfilment
# Date
# 1983-04-14   3.104256       False
# 1983-04-15   3.062307       False
# 1983-04-18   3.062307       False
# 1983-04-19   3.188156       False
# 1983-04-20   3.230105       False
# ...               ...         ...
# 2021-09-29  15.250000        True
# 2021-09-30  15.150000        True
# 2021-10-01  15.570000       False
# 2021-10-04  15.640000       False
# 2021-10-05  15.790000        True
#
# [9695 rows x 2 columns]
# https://finviz.com/chart.ashx?t=TILE&ty=c&ta=1&p=d
# <img src="https://finviz.com/chart.ashx?t=TILE&ty=c&ta=1&p=d"/>
#   2%|█▊                                                                                | 6/268 [00:12<08:54,  2.04s/it]
# SITC
#                 Close  Fulfilment
# Date
# 1993-02-02   2.239996       False
# 1993-02-03   2.274458       False
# 1993-02-04   2.274458       False
# 1993-02-05   2.239996       False
# 1993-02-08   2.262969       False
# ...               ...         ...
# 2021-09-29  15.710000        True
# 2021-09-30  15.440000       False
# 2021-10-01  16.139999        True
# 2021-10-04  16.400000        True
# 2021-10-05  16.360001        True
#
# [7220 rows x 2 columns]
# https://finviz.com/chart.ashx?t=SITC&ty=c&ta=1&p=d
# <img src="https://finviz.com/chart.ashx?t=SITC&ty=c&ta=1&p=d"/>
#   4%|███                                                                              | 10/268 [00:25<12:19,  2.87s/it]
# CNHI
#                 Close  Fulfilment
# Date
# 2013-09-30  11.062306       False
# 2013-10-01  11.434000       False
# 2013-10-02  11.416299       False
# 2013-10-03  11.159655       False
# 2013-10-04  11.186205       False
# ...               ...         ...
# 2021-09-29  16.860001       False
# 2021-09-30  16.610001       False
# 2021-10-01  16.820000       False
# 2021-10-04  16.760000       False
# 2021-10-05  16.924999        True
#
# [2019 rows x 2 columns]
# https://finviz.com/chart.ashx?t=CNHI&ty=c&ta=1&p=d
# <img src="https://finviz.com/chart.ashx?t=CNHI&ty=c&ta=1&p=d"/>
#   7%|██████                                                                           | 20/268 [00:53<13:05,  3.17s/it]
# MNRL
#                 Close  Fulfilment
# Date
# 2019-04-18  16.516436       False
# 2019-04-22  17.353867       False
# 2019-04-23  17.619194       False
# 2019-04-24  17.619194       False
# 2019-04-25  17.088545       False
# ...               ...         ...
# 2021-09-29  19.520000       False
# 2021-09-30  19.160000       False
# 2021-10-01  19.850000        True
# 2021-10-04  20.510000        True
# 2021-10-05  20.517500        True
#
# [622 rows x 2 columns]
# https://finviz.com/chart.ashx?t=MNRL&ty=c&ta=1&p=d
# <img src="https://finviz.com/chart.ashx?t=MNRL&ty=c&ta=1&p=d"/>
#   9%|██████▉                                                                          | 23/268 [01:01<11:05,  2.72s/it]
# CSTR
#                 Close  Fulfilment
# Date
# 2016-09-22  15.224844       False
# 2016-09-23  15.560939       False
# 2016-09-26  15.588711       False
# 2016-09-27  15.655735       False
# 2016-09-28  16.278135       False
# ...               ...         ...
# 2021-09-29  21.580000       False
# 2021-09-30  21.240000       False
# 2021-10-01  21.400000       False
# 2021-10-04  21.350000       False
# 2021-10-05  21.529600        True
#
# [1268 rows x 2 columns]
# https://finviz.com/chart.ashx?t=CSTR&ty=c&ta=1&p=d
# <img src="https://finviz.com/chart.ashx?t=CSTR&ty=c&ta=1&p=d"/>
#   9%|███████▌                                                                         | 25/268 [01:08<13:36,  3.36s/it]
# CCRN
#                 Close  Fulfilment
# Date
# 2001-10-25  20.370001       False
# 2001-10-26  21.100000       False
# 2001-10-29  20.250000       False
# 2001-10-30  20.000000       False
# 2001-10-31  20.389999       False
# ...               ...         ...
# 2021-09-29  21.469999        True
# 2021-09-30  21.240000       False
# 2021-10-01  21.270000       False
# 2021-10-04  21.580000        True
# 2021-10-05  21.549999        True
#
# [5021 rows x 2 columns]
# https://finviz.com/chart.ashx?t=CCRN&ty=c&ta=1&p=d
# <img src="https://finviz.com/chart.ashx?t=CCRN&ty=c&ta=1&p=d"/>
#  10%|████████▏                                                                        | 27/268 [01:16<13:44,  3.42s/it]
# VLRS
#                 Close  Fulfilment
# Date
# 2013-09-18  14.010000       False
# 2013-09-19  13.810000       False
# 2013-09-20  13.830000       False
# 2013-09-23  14.000000       False
# 2013-09-24  14.530000       False
# ...               ...         ...
# 2021-09-29  22.230000       False
# 2021-09-30  21.809999       False
# 2021-10-01  22.320000        True
# 2021-10-04  22.100000        True
# 2021-10-05  22.100000        True
#
# [2027 rows x 2 columns]
# https://finviz.com/chart.ashx?t=VLRS&ty=c&ta=1&p=d
# <img src="https://finviz.com/chart.ashx?t=VLRS&ty=c&ta=1&p=d"/>
#  11%|█████████                                                                        | 30/268 [01:24<11:22,  2.87s/it]
# ESI
#                 Close  Fulfilment
# Date
# 2013-10-22  11.860023       False
# 2013-10-23  11.860023       False
# 2013-10-25  11.612939       False
# 2013-10-28  11.612939       False
# 2013-10-29  11.711773       False
# ...               ...         ...
# 2021-09-29  22.260000       False
# 2021-09-30  21.680000       False
# 2021-10-01  22.160000       False
# 2021-10-04  22.309999       False
# 2021-10-05  22.900000        True
#
# [1963 rows x 2 columns]
# https://finviz.com/chart.ashx?t=ESI&ty=c&ta=1&p=d
# <img src="https://finviz.com/chart.ashx?t=ESI&ty=c&ta=1&p=d"/>
#  12%|█████████▎                                                                       | 31/268 [01:28<12:42,  3.22s/it]
# FFIC
#                 Close  Fulfilment
# Date
# 1995-11-21   1.995000       False
# 1995-11-22   2.034462       False
# 1995-11-24   2.034462       False
# 1995-11-27   2.008155       False
# 1995-11-28   1.981848       False
# ...               ...         ...
# 2021-09-29  22.940001        True
# 2021-09-30  22.600000       False
# 2021-10-01  23.129999       False
# 2021-10-04  23.280001       False
# 2021-10-05  23.260000        True
#
# [6512 rows x 2 columns]
# https://finviz.com/chart.ashx?t=FFIC&ty=c&ta=1&p=d
# <img src="https://finviz.com/chart.ashx?t=FFIC&ty=c&ta=1&p=d"/>
#  12%|█████████▋                                                                       | 32/268 [01:33<14:58,  3.81s/it]
# WBT
#                 Close  Fulfilment
# Date
# 2016-03-08  14.800000       False
# 2016-03-09  14.170000       False
# 2016-03-10  14.140000       False
# 2016-03-11  14.610000       False
# 2016-03-14  14.670000       False
# ...               ...         ...
# 2021-09-29  23.559999        True
# 2021-09-30  23.240000       False
# 2021-10-01  23.549999        True
# 2021-10-04  23.600000        True
# 2021-10-05  23.549999        True
#
# [1406 rows x 2 columns]
# https://finviz.com/chart.ashx?t=WBT&ty=c&ta=1&p=d
# <img src="https://finviz.com/chart.ashx?t=WBT&ty=c&ta=1&p=d"/>
#  13%|██████████▉                                                                      | 36/268 [01:44<11:52,  3.07s/it]
# ALEX
#                 Close  Fulfilment
# Date
# 2012-06-14  15.122448       False
# 2012-06-15  14.741937       False
# 2012-06-18  14.741937       False
# 2012-06-25  14.753465       False
# 2012-06-26  15.526019       False
# ...               ...         ...
# 2021-09-29  23.719999       False
# 2021-09-30  23.440001       False
# 2021-10-01  24.110001       False
# 2021-10-04  24.139999        True
# 2021-10-05  23.885000        True
#
# [2339 rows x 2 columns]
# https://finviz.com/chart.ashx?t=ALEX&ty=c&ta=1&p=d
# <img src="https://finviz.com/chart.ashx?t=ALEX&ty=c&ta=1&p=d"/>
#  16%|████████████▉                                                                    | 43/268 [01:58<06:11,  1.65s/it]
# TROX
#                 Close  Fulfilment
# Date
# 2010-12-01  11.177270       False
# 2010-12-02  11.177270       False
# 2010-12-03  12.531037       False
# 2010-12-06  12.531037       False
# 2010-12-07  12.531037       False
# ...               ...         ...
# 2021-09-29  24.309999       False
# 2021-09-30  24.650000       False
# 2021-10-01  24.889999        True
# 2021-10-04  24.559999       False
# 2021-10-05  24.940001        True
#
# [2720 rows x 2 columns]
# https://finviz.com/chart.ashx?t=TROX&ty=c&ta=1&p=d
# <img src="https://finviz.com/chart.ashx?t=TROX&ty=c&ta=1&p=d"/>
#  18%|██████████████▏                                                                  | 47/268 [02:03<04:06,  1.11s/it]
# TECK
#                 Close  Fulfilment
# Date
# 2002-07-18   3.255785       False
# 2002-07-19   3.115751       False
# 2002-07-22   2.905700       False
# 2002-07-23   2.582845       False
# 2002-07-24   2.489489       False
# ...               ...         ...
# 2021-09-29  24.910000       False
# 2021-09-30  24.910000       False
# 2021-10-01  25.190001       False
# 2021-10-04  25.820000       False
# 2021-10-05  25.750000        True
#
# [4752 rows x 2 columns]
# https://finviz.com/chart.ashx?t=TECK&ty=c&ta=1&p=d
# <img src="https://finviz.com/chart.ashx?t=TECK&ty=c&ta=1&p=d"/>
#  18%|██████████████▌                                                                  | 48/268 [02:07<07:24,  2.02s/it]
# IHRT
#                 Close  Fulfilment
# Date
# 2019-07-01  15.400000       False
# 2019-07-02  15.400000       False
# 2019-07-03  15.500000       False
# 2019-07-05  15.450000       False
# 2019-07-08  15.500000       False
# ...               ...         ...
# 2021-09-29  24.790001       False
# 2021-09-30  25.020000       False
# 2021-10-01  25.790001       False
# 2021-10-04  25.900000        True
# 2021-10-05  26.190001        True
#
# [572 rows x 2 columns]
# https://finviz.com/chart.ashx?t=IHRT&ty=c&ta=1&p=d
# <img src="https://finviz.com/chart.ashx?t=IHRT&ty=c&ta=1&p=d"/>
#  19%|███████████████▋                                                                 | 52/268 [02:18<10:34,  2.94s/it]
# KE
#                 Close  Fulfilment
# Date
# 2014-11-03   7.220000       False
# 2014-11-04   8.750000       False
# 2014-11-05  10.060000       False
# 2014-11-06  10.460000       False
# 2014-11-07   9.960000       False
# ...               ...         ...
# 2021-09-29  25.990000       False
# 2021-09-30  25.770000       False
# 2021-10-01  26.309999       False
# 2021-10-04  26.590000        True
# 2021-10-05  27.014999        True
#
# [1743 rows x 2 columns]
# https://finviz.com/chart.ashx?t=KE&ty=c&ta=1&p=d
# <img src="https://finviz.com/chart.ashx?t=KE&ty=c&ta=1&p=d"/>
#  21%|████████████████▉                                                                | 56/268 [02:27<08:57,  2.53s/it]
# SCU
#                  Close  Fulfilment
# Date
# 2007-11-14  125.957130       False
# 2007-11-15  115.272354       False
# 2007-11-16  115.066872       False
# 2007-11-19  105.738274       False
# 2007-11-20  100.067108       False
# ...                ...         ...
# 2021-09-29   27.990000        True
# 2021-09-30   27.889999        True
# 2021-10-01   28.450001        True
# 2021-10-04   28.139999        True
# 2021-10-05   28.200001        True
#
# [3497 rows x 2 columns]
# https://finviz.com/chart.ashx?t=SCU&ty=c&ta=1&p=d
# <img src="https://finviz.com/chart.ashx?t=SCU&ty=c&ta=1&p=d"/>
#  21%|█████████████████▏                                                               | 57/268 [02:30<09:30,  2.70s/it]
# MPLX
#                 Close  Fulfilment
# Date
# 2012-10-26  15.109939       False
# 2012-10-31  15.137717       False
# 2012-11-01  14.826628       False
# 2012-11-02  15.032172       False
# 2012-11-05  14.998837       False
# ...               ...         ...
# 2021-09-29  28.750000       False
# 2021-09-30  28.469999       False
# 2021-10-01  28.940001        True
# 2021-10-04  29.430000        True
# 2021-10-05  29.268700        True
#
# [2249 rows x 2 columns]
# https://finviz.com/chart.ashx?t=MPLX&ty=c&ta=1&p=d
# <img src="https://finviz.com/chart.ashx?t=MPLX&ty=c&ta=1&p=d"/>
#  29%|███████████████████████▎                                                         | 77/268 [03:04<05:42,  1.80s/it]
# TGH
#                 Close  Fulfilment
# Date
# 2007-10-10  10.196508       False
# 2007-10-11   9.776654       False
# 2007-10-12   9.848629       False
# 2007-10-15   9.782652       False
# 2007-10-16   9.902611       False
# ...               ...         ...
# 2021-09-29  36.060001       False
# 2021-09-30  34.910000       False
# 2021-10-01  35.660000       False
# 2021-10-04  34.439999       False
# 2021-10-05  35.345001        True
#
# [3522 rows x 2 columns]
# https://finviz.com/chart.ashx?t=TGH&ty=c&ta=1&p=d
# <img src="https://finviz.com/chart.ashx?t=TGH&ty=c&ta=1&p=d"/>
#  34%|███████████████████████████▊                                                     | 92/268 [03:31<04:48,  1.64s/it]
# SHOO
#                 Close  Fulfilment
# Date
# 1993-12-13   0.897756       False
# 1993-12-14   0.868321       False
# 1993-12-15   0.897756       False
# 1993-12-16   0.868321       False
# 1993-12-17   0.868321       False
# ...               ...         ...
# 2021-09-29  42.310001       False
# 2021-09-30  40.160000       False
# 2021-10-01  40.619999       False
# 2021-10-04  40.889999       False
# 2021-10-05  41.410000        True
#
# [7003 rows x 2 columns]
# https://finviz.com/chart.ashx?t=SHOO&ty=c&ta=1&p=d
# <img src="https://finviz.com/chart.ashx?t=SHOO&ty=c&ta=1&p=d"/>
#  37%|█████████████████████████████▌                                                   | 98/268 [03:44<04:07,  1.46s/it]
# MGM
#                 Close  Fulfilment
# Date
# 1988-05-02   2.583822       False
# 1988-05-03   2.583822       False
# 1988-05-04   2.583822       False
# 1988-05-05   2.583822       False
# 1988-05-06   2.583822       False
# ...               ...         ...
# 2021-09-29  43.849998       False
# 2021-09-30  43.150002       False
# 2021-10-01  44.860001       False
# 2021-10-04  44.509998       False
# 2021-10-05  44.869999        True
#
# [8216 rows x 2 columns]
# https://finviz.com/chart.ashx?t=MGM&ty=c&ta=1&p=d
# <img src="https://finviz.com/chart.ashx?t=MGM&ty=c&ta=1&p=d"/>
#  37%|█████████████████████████████▉                                                   | 99/268 [03:48<06:46,  2.41s/it]
# CSV
#                 Close  Fulfilment
# Date
# 1996-08-09  14.813519       False
# 1996-08-12  14.813519       False
# 1996-08-13  14.701291       False
# 1996-08-14  14.701291       False
# 1996-08-15  14.925738       False
# ...               ...         ...
# 2021-09-29  44.779999        True
# 2021-09-30  44.590000        True
# 2021-10-01  45.160000       False
# 2021-10-04  44.639999       False
# 2021-10-05  44.990002        True
#
# [6332 rows x 2 columns]
# https://finviz.com/chart.ashx?t=CSV&ty=c&ta=1&p=d
# <img src="https://finviz.com/chart.ashx?t=CSV&ty=c&ta=1&p=d"/>
#  40%|███████████████████████████████▋                                                | 106/268 [04:04<04:22,  1.62s/it]
# HGV
#                 Close  Fulfilment
# Date
# 2017-01-04  25.850000       False
# 2017-01-05  25.580000       False
# 2017-01-06  26.549999       False
# 2017-01-09  26.500000       False
# 2017-01-10  25.790001       False
# ...               ...         ...
# 2021-09-29  49.180000       False
# 2021-09-30  47.570000       False
# 2021-10-01  49.230000       False
# 2021-10-04  47.869999       False
# 2021-10-05  48.450001        True
#
# [1197 rows x 2 columns]
# https://finviz.com/chart.ashx?t=HGV&ty=c&ta=1&p=d
# <img src="https://finviz.com/chart.ashx?t=HGV&ty=c&ta=1&p=d"/>
#  42%|█████████████████████████████████▍                                              | 112/268 [04:23<09:35,  3.69s/it]
# OLN
#                 Close  Fulfilment
# Date
# 1973-02-21   0.581308       False
# 1973-02-22   0.581308       False
# 1973-02-23   0.567245       False
# 1973-02-26   0.567245       False
# 1973-02-27   0.567245       False
# ...               ...         ...
# 2021-09-29  49.020000       False
# 2021-09-30  48.250000       False
# 2021-10-01  49.310001       False
# 2021-10-04  48.720001       False
# 2021-10-05  49.779999        True
#
# [12241 rows x 2 columns]
# https://finviz.com/chart.ashx?t=OLN&ty=c&ta=1&p=d
# <img src="https://finviz.com/chart.ashx?t=OLN&ty=c&ta=1&p=d"/>
#  42%|█████████████████████████████████▋                                              | 113/268 [04:33<14:33,  5.63s/it]
# GDEN
#                 Close  Fulfilment
# Date
# 1999-01-04   7.296593       False
# 1999-01-05   9.147967       False
# 1999-01-06  10.345915       False
# 1999-01-07   8.167828       False
# 1999-01-08   8.603445       False
# ...               ...         ...
# 2021-09-29  49.240002       False
# 2021-09-30  49.090000       False
# 2021-10-01  49.259998       False
# 2021-10-04  48.919998       False
# 2021-10-05  49.700001        True
#
# [5724 rows x 2 columns]
# https://finviz.com/chart.ashx?t=GDEN&ty=c&ta=1&p=d
# <img src="https://finviz.com/chart.ashx?t=GDEN&ty=c&ta=1&p=d"/>
#  43%|██████████████████████████████████                                              | 114/268 [04:38<14:04,  5.48s/it]
# AB
#                 Close  Fulfilment
# Date
# 1988-04-14   0.216248       False
# 1988-04-15   0.221588       False
# 1988-04-18   0.221588       False
# 1988-04-19   0.224257       False
# 1988-04-20   0.226927       False
# ...               ...         ...
# 2021-09-29  49.799999       False
# 2021-09-30  49.580002       False
# 2021-10-01  50.790001        True
# 2021-10-04  50.330002        True
# 2021-10-05  50.605000        True
#
# [8437 rows x 2 columns]
# https://finviz.com/chart.ashx?t=AB&ty=c&ta=1&p=d
# <img src="https://finviz.com/chart.ashx?t=AB&ty=c&ta=1&p=d"/>
#  43%|██████████████████████████████████▋                                             | 116/268 [04:46<11:21,  4.48s/it]
# EPR
#                 Close  Fulfilment
# Date
# 1997-11-18   3.582678       False
# 1997-11-19   3.628608       False
# 1997-11-20   3.536745       False
# 1997-11-21   3.594160       False
# 1997-11-24   3.548230       False
# ...               ...         ...
# 2021-09-29  50.090000       False
# 2021-09-30  49.380001       False
# 2021-10-01  51.970001        True
# 2021-10-04  51.820000        True
# 2021-10-05  51.570000        True
#
# [6008 rows x 2 columns]
# https://finviz.com/chart.ashx?t=EPR&ty=c&ta=1&p=d
# <img src="https://finviz.com/chart.ashx?t=EPR&ty=c&ta=1&p=d"/>
#  46%|████████████████████████████████████▍                                           | 122/268 [04:58<05:58,  2.46s/it]
# RRR
#                 Close  Fulfilment
# Date
# 2016-04-27  17.511402       False
# 2016-04-28  17.539499       False
# 2016-04-29  17.455219       False
# 2016-05-02  17.670603       False
# 2016-05-03  17.754881       False
# ...               ...         ...
# 2021-09-29  51.889999       False
# 2021-09-30  51.220001       False
# 2021-10-01  53.669998       False
# 2021-10-04  54.119999       False
# 2021-10-05  54.580002        True
#
# [1371 rows x 2 columns]
# https://finviz.com/chart.ashx?t=RRR&ty=c&ta=1&p=d
# <img src="https://finviz.com/chart.ashx?t=RRR&ty=c&ta=1&p=d"/>
#  47%|█████████████████████████████████████▉                                          | 127/268 [05:12<06:40,  2.84s/it]
# CLDX
#                  Close  Fulfilment
# Date
# 1986-05-15  877.500000       False
# 1986-05-16  742.500000       False
# 1986-05-19  720.000000       False
# 1986-05-20  810.000000       False
# 1986-05-21  787.500000       False
# ...                ...         ...
# 2021-09-29   51.970001       False
# 2021-09-30   53.990002        True
# 2021-10-01   55.880001        True
# 2021-10-04   56.270000        True
# 2021-10-05   56.000000        True
#
# [8887 rows x 2 columns]
# https://finviz.com/chart.ashx?t=CLDX&ty=c&ta=1&p=d
# <img src="https://finviz.com/chart.ashx?t=CLDX&ty=c&ta=1&p=d"/>
#  50%|███████████████████████████████████████▋                                        | 133/268 [05:25<03:49,  1.70s/it]
# AIG
#                 Close  Fulfilment
# Date
# 1973-01-02  14.967359       False
# 1973-01-03  15.032722       False
# 1973-01-04  14.858418       False
# 1973-01-05  14.945564       False
# 1973-01-08  14.901994       False
# ...               ...         ...
# 2021-09-29  55.840000        True
# 2021-09-30  54.889999       False
# 2021-10-01  55.480000       False
# 2021-10-04  55.820000        True
# 2021-10-05  57.320000        True
#
# [10812 rows x 2 columns]
# https://finviz.com/chart.ashx?t=AIG&ty=c&ta=1&p=d
# <img src="https://finviz.com/chart.ashx?t=AIG&ty=c&ta=1&p=d"/>
#  50%|████████████████████████████████████████▎                                       | 135/268 [05:34<06:35,  2.98s/it]
# OKE
#                 Close  Fulfilment
# Date
# 1980-10-01   0.655195       False
# 1980-10-02   0.710564       False
# 1980-10-03   0.722099       False
# 1980-10-06   0.701336       False
# 1980-10-07   0.687494       False
# ...               ...         ...
# 2021-09-29  58.810001       False
# 2021-09-30  57.990002       False
# 2021-10-01  59.450001       False
# 2021-10-04  60.060001       False
# 2021-10-05  60.279999        True
#
# [10338 rows x 2 columns]
# https://finviz.com/chart.ashx?t=OKE&ty=c&ta=1&p=d
# <img src="https://finviz.com/chart.ashx?t=OKE&ty=c&ta=1&p=d"/>
#  52%|█████████████████████████████████████████▊                                      | 140/268 [05:55<08:24,  3.94s/it]
# MPC
#                 Close  Fulfilment
# Date
# 2011-06-24  13.580849       False
# 2011-06-27  13.726683       False
# 2011-06-28  14.109494       False
# 2011-06-29  14.608978       False
# 2011-06-30  15.093883       False
# ...               ...         ...
# 2021-09-29  61.930000       False
# 2021-09-30  61.810001       False
# 2021-10-01  63.560001       False
# 2021-10-04  63.020000        True
# 2021-10-05  63.290001        True
#
# [2588 rows x 2 columns]
# https://finviz.com/chart.ashx?t=MPC&ty=c&ta=1&p=d
# <img src="https://finviz.com/chart.ashx?t=MPC&ty=c&ta=1&p=d"/>
#  57%|█████████████████████████████████████████████▎                                  | 152/268 [06:19<01:59,  1.03s/it]
# SF
#                 Close  Fulfilment
# Date
# 1983-07-19   1.802433       False
# 1983-07-20   1.785744       False
# 1983-07-21   1.685608       False
# 1983-07-22   1.718987       False
# 1983-07-25   1.802433       False
# ...               ...         ...
# 2021-09-29  69.059998       False
# 2021-09-30  67.959999       False
# 2021-10-01  69.839996        True
# 2021-10-04  69.250000        True
# 2021-10-05  70.680000        True
#
# [9258 rows x 2 columns]
# https://finviz.com/chart.ashx?t=SF&ty=c&ta=1&p=d
# <img src="https://finviz.com/chart.ashx?t=SF&ty=c&ta=1&p=d"/>
#  58%|██████████████████████████████████████████████▌                                 | 156/268 [06:36<06:07,  3.28s/it]
# HIG
#                 Close  Fulfilment
# Date
# 1995-12-15  14.375696       False
# 1995-12-18  14.122867       False
# 1995-12-19  13.833900       False
# 1995-12-20  14.195107       False
# 1995-12-21  14.014503       False
# ...               ...         ...
# 2021-09-29  71.680000        True
# 2021-09-30  70.250000       False
# 2021-10-01  71.010002       False
# 2021-10-04  70.169998       False
# 2021-10-05  71.860001        True
#
# [6496 rows x 2 columns]
# https://finviz.com/chart.ashx?t=HIG&ty=c&ta=1&p=d
# <img src="https://finviz.com/chart.ashx?t=HIG&ty=c&ta=1&p=d"/>
#  60%|████████████████████████████████████████████████                                | 161/268 [06:54<06:57,  3.90s/it]
# SCHW
#                 Close  Fulfilment
# Date
# 1987-09-22   0.257476       False
# 1987-09-23   0.257476       False
# 1987-09-24   0.263327       False
# 1987-09-25   0.265278       False
# 1987-09-28   0.259426       False
# ...               ...         ...
# 2021-09-29  75.379997       False
# 2021-09-30  72.839996       False
# 2021-10-01  74.419998       False
# 2021-10-04  73.230003       False
# 2021-10-05  76.209999        True
#
# [8576 rows x 2 columns]
# https://finviz.com/chart.ashx?t=SCHW&ty=c&ta=1&p=d
# <img src="https://finviz.com/chart.ashx?t=SCHW&ty=c&ta=1&p=d"/>
#  64%|███████████████████████████████████████████████████                             | 171/268 [07:22<02:44,  1.69s/it]
# MATX
#                 Close  Fulfilment
# Date
# 1973-05-03   0.368039       False
# 1973-05-04   0.371872       False
# 1973-05-07   0.379540       False
# 1973-05-08   0.379540       False
# 1973-05-09   0.391041       False
# ...               ...         ...
# 2021-09-29  81.190002       False
# 2021-09-30  80.709999       False
# 2021-10-01  82.599998        True
# 2021-10-04  81.519997       False
# 2021-10-05  83.500000        True
#
# [12061 rows x 2 columns]
# https://finviz.com/chart.ashx?t=MATX&ty=c&ta=1&p=d
# <img src="https://finviz.com/chart.ashx?t=MATX&ty=c&ta=1&p=d"/>
#  65%|███████████████████████████████████████████████████▋                            | 173/268 [07:34<05:45,  3.64s/it]
# SIG
#                 Close  Fulfilment
# Date
# 1988-07-14  57.803326       False
# 1988-07-15  56.212387       False
# 1988-07-18  54.621490       False
# 1988-07-19  55.151760       False
# 1988-07-20  55.151760       False
# ...               ...         ...
# 2021-09-29  85.400002        True
# 2021-09-30  78.959999       False
# 2021-10-01  81.540001       False
# 2021-10-04  84.150002        True
# 2021-10-05  86.150002        True
#
# [7686 rows x 2 columns]
# https://finviz.com/chart.ashx?t=SIG&ty=c&ta=1&p=d
# <img src="https://finviz.com/chart.ashx?t=SIG&ty=c&ta=1&p=d"/>
#  67%|█████████████████████████████████████████████████████▍                          | 179/268 [08:05<06:38,  4.48s/it]
# NTAP
#                 Close  Fulfilment
# Date
# 1995-11-21   1.050717       False
# 1995-11-22   1.281363       False
# 1995-11-24   1.383872       False
# 1995-11-27   1.294177       False
# 1995-11-28   1.306990       False
# ...               ...         ...
# 2021-09-29  90.330002       False
# 2021-09-30  89.760002       False
# 2021-10-01  90.580002       False
# 2021-10-04  89.540001       False
# 2021-10-05  90.559998        True
#
# [6513 rows x 2 columns]
# https://finviz.com/chart.ashx?t=NTAP&ty=c&ta=1&p=d
# <img src="https://finviz.com/chart.ashx?t=NTAP&ty=c&ta=1&p=d"/>
#  68%|██████████████████████████████████████████████████████                          | 181/268 [08:14<06:25,  4.43s/it]
# CELH
#                 Close  Fulfilment
# Date
# 2007-01-22  40.000000       False
# 2007-01-23  31.799999       False
# 2007-01-24  35.799999       False
# 2007-01-25  40.000000       False
# 2007-01-26  38.200001       False
# ...               ...         ...
# 2021-09-29  90.580002       False
# 2021-09-30  90.089996       False
# 2021-10-01  94.190002       False
# 2021-10-04  90.620003       False
# 2021-10-05  94.589996        True
#
# [3649 rows x 2 columns]
# https://finviz.com/chart.ashx?t=CELH&ty=c&ta=1&p=d
# <img src="https://finviz.com/chart.ashx?t=CELH&ty=c&ta=1&p=d"/>
#  69%|███████████████████████████████████████████████████████▌                        | 186/268 [08:35<05:43,  4.19s/it]
# CBRE
#                  Close  Fulfilment
# Date
# 2004-06-10    6.116667       False
# 2004-06-14    6.066667       False
# 2004-06-15    6.250000       False
# 2004-06-16    6.333333       False
# 2004-06-17    6.350000       False
# ...                ...         ...
# 2021-09-29   98.610001        True
# 2021-09-30   97.360001       False
# 2021-10-01  100.449997        True
# 2021-10-04   99.040001        True
# 2021-10-05  100.246498        True
#
# [4361 rows x 2 columns]
# https://finviz.com/chart.ashx?t=CBRE&ty=c&ta=1&p=d
# <img src="https://finviz.com/chart.ashx?t=CBRE&ty=c&ta=1&p=d"/>
#  70%|███████████████████████████████████████████████████████▊                        | 187/268 [08:40<06:10,  4.58s/it]
# OAS
#                  Close  Fulfilment
# Date
# 2010-06-17   14.072157       False
# 2010-06-18   15.093522       False
# 2010-06-21   14.876010       False
# 2010-06-22   14.715240       False
# 2010-06-23   14.346414       False
# ...                ...         ...
# 2021-09-29   99.470001       False
# 2021-09-30   99.419998       False
# 2021-10-01   99.699997       False
# 2021-10-04  103.000000        True
# 2021-10-05  101.629997        True
#
# [2846 rows x 2 columns]
# https://finviz.com/chart.ashx?t=OAS&ty=c&ta=1&p=d
# <img src="https://finviz.com/chart.ashx?t=OAS&ty=c&ta=1&p=d"/>
#  75%|███████████████████████████████████████████████████████████▋                    | 200/268 [09:16<02:42,  2.40s/it]
# CZR
#                  Close  Fulfilment
# Date
# 2014-09-22    4.350000       False
# 2014-09-23    4.260000       False
# 2014-09-24    4.340000       False
# 2014-09-25    4.000000       False
# 2014-09-26    4.400000       False
# ...                ...         ...
# 2021-09-29  113.400002       False
# 2021-09-30  112.279999       False
# 2021-10-01  119.489998       False
# 2021-10-04  118.110001       False
# 2021-10-05  116.089996        True
#
# [1773 rows x 2 columns]
# https://finviz.com/chart.ashx?t=CZR&ty=c&ta=1&p=d
# <img src="https://finviz.com/chart.ashx?t=CZR&ty=c&ta=1&p=d"/>
#  77%|█████████████████████████████████████████████████████████████▊                  | 207/268 [09:39<02:52,  2.83s/it]
# WCC
#                  Close  Fulfilment
# Date
# 1999-05-12   20.000000       False
# 1999-05-13   21.062500       False
# 1999-05-14   20.125000       False
# 1999-05-17   20.000000       False
# 1999-05-18   19.625000       False
# ...                ...         ...
# 2021-09-29  117.430000       False
# 2021-09-30  115.320000       False
# 2021-10-01  120.000000        True
# 2021-10-04  119.809998        True
# 2021-10-05  121.430000        True
#
# [5638 rows x 2 columns]
# https://finviz.com/chart.ashx?t=WCC&ty=c&ta=1&p=d
# <img src="https://finviz.com/chart.ashx?t=WCC&ty=c&ta=1&p=d"/>
#  85%|████████████████████████████████████████████████████████████████████▎           | 229/268 [10:44<01:35,  2.45s/it]
# LPLA
#                  Close  Fulfilment
# Date
# 2010-11-18   25.340912       False
# 2010-11-19   25.695599       False
# 2010-11-22   25.380318       False
# 2010-11-23   25.821712       False
# 2010-11-24   25.963596       False
# ...                ...         ...
# 2021-09-29  159.220001       False
# 2021-09-30  156.759995       False
# 2021-10-01  160.179993       False
# 2021-10-04  157.690002       False
# 2021-10-05  161.529999        True
#
# [2738 rows x 2 columns]
# https://finviz.com/chart.ashx?t=LPLA&ty=c&ta=1&p=d
# <img src="https://finviz.com/chart.ashx?t=LPLA&ty=c&ta=1&p=d"/>
#  92%|█████████████████████████████████████████████████████████████████████████▍      | 246/268 [11:38<01:38,  4.49s/it]
# JLL
#                  Close  Fulfilment
# Date
# 1997-07-17   26.272057       False
# 1997-07-18   26.955931       False
# 1997-07-21   26.898939       False
# 1997-07-22   26.898939       False
# 1997-07-23   26.215071       False
# ...                ...         ...
# 2021-09-29  249.080002        True
# 2021-09-30  248.089996       False
# 2021-10-01  258.019989        True
# 2021-10-04  252.830002        True
# 2021-10-05  256.230011        True
#
# [6096 rows x 2 columns]
# https://finviz.com/chart.ashx?t=JLL&ty=c&ta=1&p=d
# <img src="https://finviz.com/chart.ashx?t=JLL&ty=c&ta=1&p=d"/>
#  94%|███████████████████████████████████████████████████████████████████████████▌    | 253/268 [11:56<00:36,  2.40s/it]
# IT
#                  Close  Fulfilment
# Date
# 1993-10-05    3.033381       False
# 1993-10-06    3.003931       False
# 1993-10-07    3.003931       False
# 1993-10-08    3.003931       False
# 1993-10-11    2.945030       False
# ...                ...         ...
# 2021-09-29  307.850006       False
# 2021-09-30  303.880005       False
# 2021-10-01  306.200012       False
# 2021-10-04  305.130005       False
# 2021-10-05  311.571289        True
#
# [7052 rows x 2 columns]
# https://finviz.com/chart.ashx?t=IT&ty=c&ta=1&p=d
# <img src="https://finviz.com/chart.ashx?t=IT&ty=c&ta=1&p=d"/>
#  96%|████████████████████████████████████████████████████████████████████████████▋   | 257/268 [12:09<00:29,  2.65s/it]
# TEAM
#                  Close  Fulfilment
# Date
# 2015-12-09   21.000000       False
# 2015-12-10   27.780001       False
# 2015-12-11   27.500000       False
# 2015-12-14   26.260000       False
# 2015-12-15   26.500000       False
# ...                ...         ...
# 2021-09-29  387.600006       False
# 2021-09-30  391.420013       False
# 2021-10-01  392.220001        True
# 2021-10-04  382.709991       False
# 2021-10-05  390.859985        True
#
# [1466 rows x 2 columns]
# https://finviz.com/chart.ashx?t=TEAM&ty=c&ta=1&p=d
# <img src="https://finviz.com/chart.ashx?t=TEAM&ty=c&ta=1&p=d"/>
#  96%|█████████████████████████████████████████████████████████████████████████████   | 258/268 [12:12<00:27,  2.80s/it]
# PANW
#                  Close  Fulfilment
# Date
# 2012-07-20   53.130001       False
# 2012-07-23   51.509998       False
# 2012-07-24   55.500000       False
# 2012-07-25   58.950001       False
# 2012-07-26   59.880001       False
# ...                ...         ...
# 2021-09-29  473.070007       False
# 2021-09-30  479.000000       False
# 2021-10-01  486.510010        True
# 2021-10-04  469.540009       False
# 2021-10-05  478.010010        True
#
# [2318 rows x 2 columns]
# https://finviz.com/chart.ashx?t=PANW&ty=c&ta=1&p=d
# <img src="https://finviz.com/chart.ashx?t=PANW&ty=c&ta=1&p=d"/>
# 100%|████████████████████████████████████████████████████████████████████████████████| 268/268 [12:39<00:00,  2.83s/it]

# %%
from datetime import datetime
now = datetime.now() # current date and time
year = now.strftime("%Y")
month = now.strftime("%m")
day = now.strftime("%d")

# csv list of name,tickers
tickers = tickerList
dict = {'tickers': tickers}
df = pd.DataFrame(dict) 
    
# saving the dataframe 
df.to_csv(r'csv\ticker_VCP_'+year+month+day+'.csv')
